# %%
import os, requests, re, time, numpy as np, pandas as pd, pickle
from IPython.display import clear_output

import xmltodict

# %%
pd.set_option('display.max_columns', None)

# %%
def get_node_names(parent):
    node_names = []
    
    for item in parent.items():
        if item[1] != None:
            if type(item[1]) == str:
                node_names.append(item[0])
            
            elif type(item[1]) == list:
                try:
                    child_list_node_names = get_node_names(item[1][0])
                    for child in child_list_node_names:
                        string_name = item[0] + '.' + child
                        node_names.append(string_name)
                except AttributeError:
                    pass
            
            else:
                child_node_names = get_node_names(item[1])
                for child in child_node_names:
                    string_name = item[0] + '.' + child
                    node_names.append(string_name)
            
    return node_names

def get_node_values(parent):
    value_list = []
    for item in parent.items():
        if item[1] != None:
            if type(item[1]) == str:
                value_list.append(item[1])
            
            elif type(item[1]) == list:
                try:
                    child_values = get_node_values(item[1][0])
                    for value in child_values:
                        value_list.append(value)
                except AttributeError:
                    pass
            
            else:
                child_values = get_node_values(item[1])
                for value in child_values:
                    value_list.append(value)
    
    return value_list

# %%
monroe_html = 'https://s3.amazonaws.com/irs-form-990/201911159349300636_public.xml'
monroe_baseline = xmltodict.parse(requests.get(monroe_html).content)
monroe_node_list = get_node_names(monroe_baseline)
monroe_dictionary = dict(zip(monroe_node_list, get_node_values(monroe_baseline)))
key_list = list(monroe_dictionary.keys())

# %%
with open('affiliates annual links', 'rb') as infile:
    html_list = pickle.load(infile)

# %%
main_list = []
main_list.append(monroe_dictionary)
count = 1
for html in html_list:
    print("Gathering data for Affiliate #"+ str(count))
    data = xmltodict.parse(requests.get(html).content)
    node_list = get_node_names(data)
    node_values = get_node_values(data)
    temp_dict = dict(zip(node_list,node_values))
    new_dict = {}
    for key in key_list:
        new_dict[key] = temp_dict.get(key)
    clear_output(wait=True)
    main_list.append(new_dict)
    count += 1
    time.sleep(0.2)
# Out:
# Gathering data for Affiliate #4771

# %%
df = pd.DataFrame(main_list, columns = monroe_node_list)

# %%
df
# Out:
#                  Return.@xmlns                          Return.@xmlns:xsi  \
# 0     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 1     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 2     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 3     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4     http://www.irs.gov/efile                                       None
# 5     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 6     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 7     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 8     http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 9     http://www.irs.gov/efile                                       None
# 10    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 11    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 12    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 13    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 14    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 15    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 16    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 17    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 18    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 19    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 20    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 21    http://www.irs.gov/efile                                       None
# 22    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 23    http://www.irs.gov/efile                                       None
# 24    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 25    http://www.irs.gov/efile                                       None
# 26    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 27    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 28    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 29    http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# ...                        ...                                        ...
# 4742  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4743  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4744  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4745  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4746  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4747  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4748  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4749  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4750  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4751  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4752  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4753  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4754  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4755  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4756  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4757  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4758  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4759  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4760  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4761  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4762  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4763  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4764  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4765  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4766  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4767  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4768  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4769  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4770  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
# 4771  http://www.irs.gov/efile  http://www.w3.org/2001/XMLSchema-instance
#
#      Return.@xsi:schemaLocation Return.@returnVersion  \
# 0      http://www.irs.gov/efile              2017v2.3
# 1      http://www.irs.gov/efile              2013v3.1
# 2      http://www.irs.gov/efile              2013v3.0
# 3                          None              2013v3.1
# 4                          None              2013v3.1
# 5      http://www.irs.gov/efile              2013v3.0
# 6      http://www.irs.gov/efile              2013v3.0
# 7      http://www.irs.gov/efile              2013v3.0
# 8      http://www.irs.gov/efile              2013v3.0
# 9                          None              2013v3.1
# 10                         None              2013v3.1
# 11                         None              2013v3.1
# 12     http://www.irs.gov/efile              2013v3.1
# 13                         None              2013v3.1
# 14     http://www.irs.gov/efile              2013v3.0
# 15                         None              2013v3.1
# 16     http://www.irs.gov/efile              2013v3.0
# 17     http://www.irs.gov/efile              2013v3.0
# 18     http://www.irs.gov/efile              2013v3.1
# 19     http://www.irs.gov/efile              2013v3.1
# 20     http://www.irs.gov/efile              2013v3.0
# 21                         None              2013v3.0
# 22     http://www.irs.gov/efile              2013v3.0
# 23                         None              2013v3.1
# 24                         None              2013v3.1
# 25                         None              2013v3.1
# 26                         None              2013v3.1
# 27     http://www.irs.gov/efile              2013v3.0
# 28                         None              2013v3.1
# 29     http://www.irs.gov/efile              2013v3.0
# ...                         ...                   ...
# 4742   http://www.irs.gov/efile              2017v2.3
# 4743   http://www.irs.gov/efile              2017v2.2
# 4744                       None              2017v2.3
# 4745   http://www.irs.gov/efile              2017v2.3
# 4746                       None              2017v2.0
# 4747   http://www.irs.gov/efile              2018v3.1
# 4748                       None              2017v2.3
# 4749   http://www.irs.gov/efile              2017v2.3
# 4750   http://www.irs.gov/efile              2017v2.2
# 4751   http://www.irs.gov/efile              2018v3.1
# 4752   http://www.irs.gov/efile              2017v2.2
# 4753   http://www.irs.gov/efile              2017v2.3
# 4754   http://www.irs.gov/efile              2017v2.2
# 4755                       None              2017v2.2
# 4756   http://www.irs.gov/efile              2017v2.3
# 4757                       None              2017v2.3
# 4758                       None              2017v2.3
# 4759   http://www.irs.gov/efile              2017v2.3
# 4760   http://www.irs.gov/efile              2017v2.3
# 4761   http://www.irs.gov/efile              2017v2.2
# 4762   http://www.irs.gov/efile              2018v3.1
# 4763                       None              2017v2.3
# 4764   http://www.irs.gov/efile              2017v2.3
# 4765   http://www.irs.gov/efile              2017v2.3
# 4766                       None              2017v2.3
# 4767   http://www.irs.gov/efile              2017v2.3
# 4768   http://www.irs.gov/efile              2017v2.2
# 4769   http://www.irs.gov/efile              2017v2.3
# 4770   http://www.irs.gov/efile              2017v2.3
# 4771                       None              2017v2.3
#
#      Return.ReturnHeader.@binaryAttachmentCnt Return.ReturnHeader.ReturnTs  \
# 0                                           0    2019-04-25T14:07:45-05:00
# 1                                           0    2014-11-10T12:37:38-08:00
# 2                                           0    2014-11-10T07:27:18-06:00
# 3                                           0    2014-11-10T08:11:44-06:00
# 4                                           0    2014-11-11T17:30:01-05:00
# 5                                           0    2014-11-13T11:04:54-06:00
# 6                                           0    2014-11-14T10:30:27-06:00
# 7                                           0    2014-11-20T13:17:11-06:00
# 8                                           0    2014-12-09T16:04:35-06:00
# 9                                           0    2014-12-17T16:33:56-05:00
# 10                                          0    2014-12-17T09:23:09-06:00
# 11                                          0    2014-12-15T13:17:02-06:00
# 12                                          0    2014-11-14T09:09:21-08:00
# 13                                          0    2014-12-15T08:26:14-06:00
# 14                                          0    2014-12-09T16:49:39-06:00
# 15                                          0    2014-12-12T10:37:47-06:00
# 16                                          0    2014-12-15T09:56:53-06:00
# 17                                          0    2014-12-15T09:21:36-06:00
# 18                                          0    2014-11-14T13:09:44-08:00
# 19                                          0    2014-11-14T10:37:25-08:00
# 20                                          0    2014-12-15T09:21:17-06:00
# 21                                          0         2014-12-18T21:45:42Z
# 22                                          0    2014-12-01T12:31:02-06:00
# 23                                          0    2014-11-17T09:55:17-05:00
# 24                                          0    2014-12-03T12:22:32-06:00
# 25                                          0    2014-11-13T16:55:27-05:00
# 26                                          0    2014-11-14T08:25:45-06:00
# 27                                          0    2014-11-17T11:15:38-06:00
# 28                                          0    2014-11-14T12:50:10-06:00
# 29                                          0    2014-11-17T07:47:31-06:00
# ...                                       ...                          ...
# 4742                                        0    2019-05-15T09:41:18-05:00
# 4743                                        0    2019-05-15T06:16:09-07:00
# 4744                                        0    2019-05-15T10:56:22-05:00
# 4745                                        0    2019-05-14T12:07:32-05:00
# 4746                                        0    2019-05-13T22:10:20-07:00
# 4747                                        0    2019-05-14T08:10:37-07:00
# 4748                                        0    2019-05-14T14:59:56-05:00
# 4749                                        0    2019-05-14T15:53:00-05:00
# 4750                                        0    2019-05-14T12:41:14-07:00
# 4751                                        0    2019-05-15T13:51:29-07:00
# 4752                                        0    2019-05-15T06:20:54-07:00
# 4753                                        0    2019-05-15T10:22:19-05:00
# 4754                                        0    2019-05-14T16:27:36-07:00
# 4755                                        0    2019-05-15T11:30:35-05:00
# 4756                                        0    2019-05-15T12:03:17-05:00
# 4757                                        0    2019-05-15T16:55:37-05:00
# 4758                                        0    2019-05-15T16:37:30-05:00
# 4759                                        0    2019-05-15T18:26:09-05:00
# 4760                                        0    2019-05-09T18:01:35-05:00
# 4761                                        0    2019-05-15T19:04:50-07:00
# 4762                                        0    2019-06-17T15:37:35-05:00
# 4763                                        0    2019-05-13T11:24:22-05:00
# 4764                                        0    2019-05-15T15:44:18-05:00
# 4765                                        0    2019-05-14T14:26:28-05:00
# 4766                                        0    2019-05-15T13:27:23-05:00
# 4767                                        0    2019-05-15T13:46:02-05:00
# 4768                                        0    2019-06-17T08:47:45-07:00
# 4769                                        0    2019-05-15T13:18:43-05:00
# 4770                                        0    2019-05-15T11:35:29-05:00
# 4771                                        0    2019-05-15T13:43:19-05:00
#
#      Return.ReturnHeader.TaxPeriodEndDt  \
# 0                            2018-06-30
# 1                            2014-06-30
# 2                            2014-06-30
# 3                            2014-06-30
# 4                            2014-06-30
# 5                            2014-06-30
# 6                            2014-06-30
# 7                            2014-06-30
# 8                            2014-06-30
# 9                            2014-06-30
# 10                           2014-06-30
# 11                           2014-06-30
# 12                           2014-06-30
# 13                           2014-06-30
# 14                           2014-06-30
# 15                           2014-06-30
# 16                           2014-06-30
# 17                           2014-06-30
# 18                           2013-12-31
# 19                           2014-06-30
# 20                           2014-06-30
# 21                           2014-06-30
# 22                           2014-06-30
# 23                           2013-12-31
# 24                           2014-06-30
# 25                           2014-06-30
# 26                           2013-12-31
# 27                           2014-06-30
# 28                           2014-06-30
# 29                           2014-06-30
# ...                                 ...
# 4742                         2018-06-30
# 4743                         2018-06-30
# 4744                         2018-06-30
# 4745                         2018-06-30
# 4746                         2018-06-30
# 4747                         2018-12-31
# 4748                         2018-06-30
# 4749                         2018-06-30
# 4750                         2018-06-30
# 4751                         2018-12-31
# 4752                         2018-06-30
# 4753                         2018-06-30
# 4754                         2018-06-30
# 4755                         2018-06-30
# 4756                         2018-06-30
# 4757                         2018-06-30
# 4758                         2018-06-30
# 4759                         2018-06-30
# 4760                         2018-06-30
# 4761                         2018-06-30
# 4762                         2018-12-31
# 4763                         2018-06-30
# 4764                         2018-06-30
# 4765                         2018-06-30
# 4766                         2018-06-30
# 4767                         2018-06-30
# 4768                         2018-06-30
# 4769                         2018-06-30
# 4770                         2018-06-30
# 4771                         2018-06-30
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerFirmEIN  \
# 0                                             311119890
# 1                                                  None
# 2                                             470608676
# 3                                             351902288
# 4                                             251813350
# 5                                             310918847
# 6                                             383086068
# 7                                             431064657
# 8                                             351515068
# 9                                             561283928
# 10                                            391658423
# 11                                            208032022
# 12                                                 None
# 13                                            582271924
# 14                                            390974031
# 15                                            953655325
# 16                                            742483487
# 17                                            410746749
# 18                                                 None
# 19                                                 None
# 20                                            410746749
# 21                                                 None
# 22                                            611227965
# 23                                            331002805
# 24                                            840817888
# 25                                            271539356
# 26                                            480969601
# 27                                            640736635
# 28                                            382706146
# 29                                            382272300
# ...                                                 ...
# 4742                                          410746749
# 4743                                          203859496
# 4744                                          208075205
# 4745                                          410746749
# 4746                                               None
# 4747                                               None
# 4748                                          570846159
# 4749                                          450250958
# 4750                                               None
# 4751                                          571092862
# 4752                                               None
# 4753                                          560574444
# 4754                                          200851206
# 4755                                          223708574
# 4756                                          910870697
# 4757                                          621110839
# 4758                                          621110839
# 4759                                          410746749
# 4760                                          930623286
# 4761                                               None
# 4762                                          221914888
# 4763                                          411414667
# 4764                                          521855942
# 4765                                          391248105
# 4766                                          351519864
# 4767                                          351307701
# 4768                                          454038737
# 4769                                          930743240
# 4770                                          581374304
# 4771                                          274431954
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerFirmName.BusinessNameLine1Txt  \
# 0                                Barnes Dennig & Co LTD
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 4742                             CLIFTONLARSONALLEN LLP
# 4743                        Vieira & Associates CPAs PC
# 4744                            MAGERS & ASSOCIATES LLC
# 4745                             CLIFTONLARSONALLEN LLP
# 4746                                               None
# 4747                                  TOCCO TAX SERVICE
# 4748                    CLINE BRANDT KOCHENOWER & CO PA
# 4749                                    Eide Bailly LLP
# 4750                   Whitley Gahm & Rayburn CPAs PLLC
# 4751                                Craig Martin CPA PA
# 4752                                   Black Marlin CPA
# 4753                                 CHERRY BEKAERT LLP
# 4754                                 JEANINE J MAYS CPA
# 4755                             BARBARA A SERRIDGE CPA
# 4756                             AIKEN & SANDERS INC PS
# 4757                     ALEXANDER THOMPSON ARNOLD PLLC
# 4758                     ALEXANDER THOMPSON ARNOLD PLLC
# 4759                             CliftonLarsonAllen LLP
# 4760                      ALDRICH CPAS AND ADVISORS LLP
# 4761                                Keith H Argueta LLC
# 4762                                     NISIVOCCIA LLP
# 4763              ESTERBROOKS SCOTT SIGNORELLI ETAL LTD
# 4764                                     TATE AND TRYON
# 4765                            ANDERSON HAGER & MOE SC
# 4766                           GIRARDOT STRAUCH & CO PC
# 4767                       KRUGGEL LAWTON & COMPANY LLC
# 4768                             Hemann Grover & Co LTD
# 4769                       HOFFMAN STEWART & SCHMIDT PC
# 4770                       ROBINSON GRIMES & COMPANY PC
# 4771                                 DOANE CPA FIRM LLC
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.AddressLine1Txt  \
# 0                        5750 Castle Creek Pkwy Ste 245
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 4742                             600 3RD AVE SE STE 300
# 4743                              111 Grant Ave Ste 106
# 4744                               165 WELLS RD STE 405
# 4745                  101 NORTH SECOND STREET SUITE 200
# 4746                                               None
# 4747                                    409 OHIO STREET
# 4748                            1225 W FLOYD BAKER BLVD
# 4749                            5441 Kietzke Ln Ste 150
# 4750                                         PO Box 369
# 4751                                         PO Box 783
# 4752                              200-1 Nat Turner Blvd
# 4753                      1111 METROPOLITAN AVE STE 900
# 4754                      2533 MERRYCHASE DRIVE STE 700
# 4755                                        30 NUNN AVE
# 4756                                   343 W WISHKAH ST
# 4757                                    227 OIL WELL RD
# 4758                                    185 N CHURCH ST
# 4759                         1325 4th Avenue Suite 1705
# 4760                           680 HAWTHORNE AVE SE 140
# 4761                             2100 Travis St Ste 240
# 4762                            200 VALLEY RD SUITE 300
# 4763                           302 W SUPERIOR ST STE200
# 4764                         2021 L STREET NW SUITE 400
# 4765                                         PO BOX 986
# 4766                                        PO BOX 1497
# 4767                                    526 UPTON DRIVE
# 4768                              404 South Main Street
# 4769                     3 CENTERPOINTE DRIVE SUITE 300
# 4770                                        PO BOX 4299
# 4771                            1116 ARSENAL ST STE 200
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.CityNm  \
# 0                                          Indianapolis
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 4742                                       CEDAR RAPIDS
# 4743                                           Endicott
# 4744                                        ORANGE PARK
# 4745                                            MANKATO
# 4746                                               None
# 4747                                           LOCKPORT
# 4748                                            GAFFNEY
# 4749                                               Reno
# 4750                                            Grayson
# 4751                                             Marion
# 4752                                       Newport News
# 4753                                          CHARLOTTE
# 4754                                       CAMERON PARK
# 4755                                         WASHINGTON
# 4756                                           ABERDEEN
# 4757                                            JACKSON
# 4758                                          DYERSBURG
# 4759                                            Seattle
# 4760                                              SALEM
# 4761                                            Houston
# 4762                                       MT ARLINGTON
# 4763                                             DULUTH
# 4764                                         WASHINGTON
# 4765                                            HAYWARD
# 4766                                          LAFAYETTE
# 4767                                          ST JOSEPH
# 4768                                           Zumbrota
# 4769                                        LAKE OSWEGO
# 4770                                           COLUMBUS
# 4771                                          WATERTOWN
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.StateAbbreviationCd  \
# 0                                                    IN
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 4742                                                 IA
# 4743                                                 NY
# 4744                                                 FL
# 4745                                                 MN
# 4746                                               None
# 4747                                                 NY
# 4748                                                 SC
# 4749                                                 NV
# 4750                                                 KY
# 4751                                                 SC
# 4752                                                 VA
# 4753                                                 NC
# 4754                                                 CA
# 4755                                                 NJ
# 4756                                                 WA
# 4757                                                 TN
# 4758                                                 TN
# 4759                                                 WA
# 4760                                                 OR
# 4761                                                 TX
# 4762                                                 NJ
# 4763                                                 MN
# 4764                                                 DC
# 4765                                                 WI
# 4766                                                 IN
# 4767                                                 MI
# 4768                                                 MN
# 4769                                                 OR
# 4770                                                 GA
# 4771                                                 NY
#
#      Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.ZIPCd  \
# 0                                                 46250
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# 5                                                  None
# 6                                                  None
# 7                                                  None
# 8                                                  None
# 9                                                  None
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# ...                                                 ...
# 4742                                              52401
# 4743                                              13760
# 4744                                          320733037
# 4745                                              56001
# 4746                                               None
# 4747                                              14094
# 4748                                              29341
# 4749                                          895112094
# 4750                                              41143
# 4751                                              29571
# 4752                                              23606
# 4753                                              28204
# 4754                                              95682
# 4755                                              07882
# 4756                                              98520
# 4757                                              38305
# 4758                                              38024
# 4759                                          981012528
# 4760                                              97301
# 4761                                              77002
# 4762                                              07856
# 4763                                              55802
# 4764                                              20036
# 4765                                              54843
# 4766                                              47902
# 4767                                              49085
# 4768                                          559921680
# 4769                                          970358663
# 4770                                              31914
# 4771                                          136018570
#
#      Return.ReturnHeader.ReturnTypeCd Return.ReturnHeader.TaxPeriodBeginDt  \
# 0                                 990                           2017-07-01
# 1                                 990                           2013-07-01
# 2                                 990                           2013-07-01
# 3                                 990                           2013-07-01
# 4                                 990                           2013-07-01
# 5                                 990                           2013-07-01
# 6                                 990                           2013-07-01
# 7                                 990                           2013-07-01
# 8                                 990                           2013-07-01
# 9                                 990                           2013-07-01
# 10                                990                           2013-07-01
# 11                                990                           2013-07-01
# 12                                990                           2013-07-01
# 13                                990                           2013-07-01
# 14                                990                           2013-07-01
# 15                                990                           2013-07-01
# 16                                990                           2013-07-01
# 17                                990                           2013-07-01
# 18                                990                           2013-01-01
# 19                                990                           2013-07-01
# 20                                990                           2013-07-01
# 21                                990                           2013-07-01
# 22                                990                           2013-07-01
# 23                                990                           2013-01-01
# 24                                990                           2013-07-01
# 25                                990                           2013-07-01
# 26                                990                           2013-01-01
# 27                                990                           2013-07-01
# 28                                990                           2013-07-01
# 29                                990                           2013-07-01
# ...                               ...                                  ...
# 4742                              990                           2017-07-01
# 4743                              990                           2017-07-01
# 4744                              990                           2017-07-01
# 4745                              990                           2017-07-01
# 4746                              990                           2017-07-01
# 4747                              990                           2018-01-01
# 4748                              990                           2017-07-01
# 4749                              990                           2017-07-01
# 4750                              990                           2017-07-01
# 4751                              990                           2018-01-01
# 4752                              990                           2017-07-01
# 4753                              990                           2017-07-01
# 4754                              990                           2017-07-01
# 4755                              990                           2017-07-01
# 4756                              990                           2017-07-01
# 4757                              990                           2017-07-01
# 4758                              990                           2017-07-01
# 4759                              990                           2017-07-01
# 4760                              990                           2017-07-01
# 4761                              990                           2017-07-01
# 4762                              990                           2018-01-01
# 4763                              990                           2017-07-01
# 4764                              990                           2017-07-01
# 4765                              990                           2017-07-01
# 4766                              990                           2017-07-01
# 4767                              990                           2017-07-01
# 4768                              990                           2017-07-01
# 4769                              990                           2017-07-01
# 4770                              990                           2017-07-01
# 4771                              990                           2017-07-01
#
#      Return.ReturnHeader.Filer.EIN  \
# 0                        351753977
# 1                        460430669
# ...
# 4752                                               None
# 4753                                                  0
# 4754                                               None
# 4755                                              false
# 4756                                               None
# 4757                                               None
# 4758                                               None
# 4759                                                  1
# 4760                                               None
# 4761                                               None
# 4762                                                  0
# 4763                                              false
# 4764                                               None
# 4765                                               None
# 4766                                              false
# 4767                                               None
# 4768                                               None
# 4769                                                  0
# 4770                                               None
# 4771                                               None
#
#      Return.ReturnData.IRS990ScheduleO.@documentId  \
# 0                                 RetDoc1044400001
# 1                                  IRS990ScheduleO
# 2                                 RetDoc1044400001
# 3                                          RetDoc9
# 4                                             990O
# 5                                 RetDoc1044400001
# 6                                 RetDoc1044400001
# 7                                 RetDoc1044400001
# 8                                 RetDoc1044400001
# 9                                             990O
# 10                                         RetDoc7
# 11                                         RetDoc5
# 12                                        00000004
# 13                                         RetDoc7
# 14                                RetDoc1044400001
# 15                                         RetDoc6
# 16                                RetDoc1044400001
# 17                                RetDoc1044400001
# 18                                 IRS990ScheduleO
# 19                                 IRS990ScheduleO
# 20                                RetDoc1044400001
# 21                                               7
# 22                                RetDoc1044400001
# 23                                            990O
# 24                                         RetDoc7
# 25                                            990O
# 26                                         RetDoc5
# 27                                RetDoc1044400001
# 28                                         RetDoc7
# 29                                RetDoc1044400001
# ...                                            ...
# 4742                              RetDoc1044400001
# 4743                               IRS990ScheduleO
# 4744                                       RetDoc4
# 4745                              RetDoc1044400001
# 4746                                       R000005
# 4747                            IRS990ScheduleO-01
# 4748                                       RetDoc5
# 4749                              RetDoc1044400001
# 4750                                      00000005
# 4751                               IRS990ScheduleO
# 4752                                      00000004
# 4753                              RetDoc1044400001
# 4754                               IRS990ScheduleO
# 4755                                   DOCIDSCHEDO
# 4756                              RetDoc1044400001
# 4757                                       RetDoc4
# 4758                                       RetDoc5
# 4759                              RetDoc1044400001
# 4760                              RetDoc1044400001
# 4761                                      00000006
# 4762                              RetDoc1044400001
# 4763                                       RetDoc5
# 4764                              RetDoc1044400001
# 4765                              RetDoc1044400001
# 4766                                       RetDoc7
# 4767                              RetDoc1044400001
# 4768                               IRS990ScheduleO
# 4769                              RetDoc1044400001
# 4770                              RetDoc1044400001
# 4771                                       RetDoc5
#
#      Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.FormAndLineReferenceDesc  \
# 0                 Form 990, Part VI, Section A, line 7a
# 1     Form 990, Part VI, Line 11b: Form 990 Review P...
# 2                 Form 990, Part VI, Section B, line 11
# 3                     FORM 990 - ORGANIZATION'S MISSION
# 4     Officer directors etc family relationship Part...
# 5                 Form 990, Part VI, Section B, line 11
# 6                 Form 990, Part VI, Section B, line 11
# 7                 FORM 990, PART VI, SECTION B, LINE 11
# 8                 FORM 990, PART VI, SECTION B, LINE 11
# 9        Form 990 governing body review Part VI line 11
# 10                  FORM 990, PAGE 6, PART VI, LINE 11B
# 11                  FORM 990, PAGE 2, PART III, LINE 4D
# 12                                      Pt VI, Line 11b
# 13                    FORM 990 - ORGANIZATION'S MISSION
# 14                 FORM 990, PART VI, SECTION A, LINE 3
# 15                    FORM 990, PAGE 6, PART VI, LINE 2
# 16                FORM 990, PART VI, SECTION B, LINE 11
# 17                FORM 990, PART VI, SECTION A, LINE 7A
# 18    Form 990, Part VI, Line 11b: Form 990 Review P...
# 19    Form 990, Part VI, Line 11b: Form 990 Review P...
# 20                            FORM 990, PART V, LINE 2A
# 21                                     FORM 990 PART VI
# 22                FORM 990, PART VI, SECTION B, LINE 11
# 23       Form 990 governing body review Part VI line 11
# 24                  FORM 990, PAGE 6, PART VI, LINE 11B
# 25       Form 990 governing body review Part VI line 11
# 26                  FORM 990, PAGE 6, PART VI, LINE 11B
# 27                FORM 990, PART VI, SECTION B, LINE 11
# 28                     FORM 990, PAGE 1, PART I, LINE 6
# 29                FORM 990, PART VI, SECTION B, LINE 11
# ...                                                 ...
# 4742               FORM 990, PART VI, SECTION A, LINE 1
# 4743  Form 990, Part VI, Line 11b: Form 990 Review P...
# 4744                FORM 990, PAGE 6, PART VI, LINE 11B
# 4745             FORM 990, PART VI, SECTION B, LINE 11B
# 4746               Form 990, Part VI, Section A, Line 2
# 4747                                    Pt VI, Line 11b
# 4748                  FORM 990 - ORGANIZATION'S MISSION
# 4749              Form 990, Part VI, Section A, line 8b
# 4750                                    Pt VI, Line 11b
# 4751  Form 990, Part VI, Line 11b: Form 990 Review P...
# 4752                                    Pt VI, Line 11b
# 4753                         FORM 990, PART III, LINE 2
# 4754  Form 990, Part VI, Line 11b: Form 990 Review P...
# 4755                         PART VI, SECTION A, LINE 2
# 4756             FORM 990, PART VI, SECTION B, LINE 11B
# 4757                   FORM 990, PAGE 1, PART I, LINE 6
# 4758                  FORM 990 - ORGANIZATION'S MISSION
# 4759             Form 990, Part VI, Section B, line 11b
# 4760               FORM 990, PART VI, SECTION A, LINE 4
# 4761                                    Pt VI, Line 11b
# 4762             FORM 990, PART VI, SECTION B, LINE 11B
# 4763                                  FORM 990, PART VI
# 4764             FORM 990, PART VI, SECTION B, LINE 11B
# 4765             FORM 990, PART VI, SECTION B, LINE 11B
# 4766                   FORM 990, PAGE 1, PART I, LINE 6
# 4767             FORM 990, PART VI, SECTION B, LINE 11B
# 4768  Form 990, Part VI, Line 11b: Form 990 Review P...
# 4769             FORM 990, PART VI, SECTION B, LINE 11B
# 4770             FORM 990, PART VI, SECTION B, LINE 11B
# 4771                   FORM 990, PAGE 1, PART I, LINE 6
#
#      Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.ExplanationTxt
# 0     Line 7a explanation - Board nominations come f...
# 1     THE FORM 990 WAS PRESENTED TO THE BOARD FOR RE...
# 2     TAX RETURN WAS GIVEN TO BOARD FOR REVIEW BEFOR...
# 3     SEEKING TO PUT GOD'S LOVE INTO ACTION, HABITAT...
# 4     CLAIR WEAVER - BOARD MEMBER AND ERIC WEAVER - ...
# 5     THE 990 IS PRESENTED TO THE GOVERNING BOARD ME...
# 6     THE BOARD REVIEWS THE 990 AT ITS REGULARLY SCH...
# 7     A PRELIMINARY COPY OF THE 990 WAS PROVIDED TO ...
# 8     THE FORM 990 WILL BE REVIEWED BY THE BOARD OF ...
# 9                   NO REVIEW WAS OR WILL BE CONDUCTED.
# 10    THE PRESIDENT AND TREASURER OF THE BOARD OF DI...
# 11    BUILD HOMES AND PROVIDE NO INTEREST FINANCING ...
# 12    AVAILABLE FOR REVIEW BY BOARD MEMBERS AT MONTH...
# 13    TO SPONSOR SPECIFIC PROJECTS IN HABITAT DEVELO...
# 14    THE ORGANIZATION LEASES ITS EMPLOYEES, INCLUDI...
# 15       BARB MYERS JIM MYERS DIRECTOR DIRECTOR MARRIED
# 16    A COPY OF THE FORM 990 WAS PRESENTED TO THE OR...
# 17    THE BOARD OF THE FILING ORGANIZATION IS APPOIN...
# 18    THE ORGANIZATION'S FORM 990 IS REVIEWED AND AP...
# 19    Draft copy of 990 is presented to Executive Di...
# 20    THE TOTAL NUMBER OF INDIVIDUALS REPORTED ON FO...
# 21    PART VI SECTION B LINE 11A COPY OF RETURN IS G...
# 22    THE DRAFT IS REVIEWED BY THE FINANCE COMMITTEE...
# 23    Approved by Treasurer and presented to complet...
# 24    REVIEWED IN DETAIL BY EXECUTIVE COMMITTEE PRIO...
# 25    The 990 is reviewed by the officers and is mad...
# 26    THERE IS A DISCUSSION AND APPROVAL BY BOARD AN...
# 27    BOARD MEMBERS REVIEW A COPY AT A BOARD MEMBER ...
# 28    VOLUNTEER AT ONE OF OUR CONSTRUCTION SITES: CO...
# 29    THE BOARD OF DIRECTORS, OR AN AVAILABLE BOARD ...
# ...                                                 ...
# 4742  THE OFFICERS OF THE ORGANIZATION AND THE IMMED...
# 4743                                  MANAGEMENT REVIEW
# 4744                NO REVIEW WAS OR WILL BE CONDUCTED.
# 4745  THE FORM 990 IS FIRST REVIEWED BY MANAGEMENT A...
# 4746  The Board Treasurer, Angela Hinnegan, is relat...
# 4747  The organization does not currently review For...
# 4748  OUR MISSION IS TO EMPOWER FAMILIES, BUILD COMM...
# 4749  There are no committees with authority to act ...
# 4750  The examination and discussion of each year's ...
# 4751    THE OFFICERS REVEIW THE RETURNS PRIOR TO FILING
# 4752               The Treasurer reviews the tax return
# 4753  DISASTER RECOVERY - IN RESPONSE TO DAMAGE FROM...
# 4754  EX DIRECTOR AND TREASURER REVIEWS AND REPORTS ...
# 4755    Several Board members are related to each other
# 4756  FORM 990 WAS PROVIDED TO BOARD MEMBERS AND THE...
# 4757  THE MAJORITY OF VOLUNTEERS WORKED IN THE CONST...
# 4758  HABITAT IS AN AFFILIATE OF HABITAT FOR HUMANIT...
# 4759  Reviewed by Finance Committee of the Board of ...
# 4760  THE ORGANIZATION'S BYLAWS WERE AMENDED MAY 15,...
# 4761  The treasurer reviews the 990 and makes it ava...
# 4762  MORRIS HABITAT FOR HUMANITY, INC. HAS ITS FORM...
# 4763  LINE15B. ANSWERED "NO" AS THE ORGANIZATION HAS...
# 4764  THE 990 TAX RETURN IS REVIEWED BY THE ORGANIZA...
# 4765  BOARD OF DIRECTORS REVIEWS FORM 990 AFTER IT I...
# 4766  PROVIDE LABOR TO CONSTRUCT HOMES. PROVIDE COUN...
# 4767  THE FORM 990 WAS PROVIDED TO THE EXECUTIVE DIR...
# 4768  Form 990 is given to the governing body and th...
# 4769  THE FORM 990 IS REVIEWED BY THE VICE PRESIDENT...
# 4770  THE ORGANIZATION'S FORM 990 IS PREPARED BY A C...
# 4771  VOLUNTEERS PROVIDE TIME AND SERVICES IN CONSTR...
#
# [4772 rows x 470 columns]

# %%
df.to_csv('affiliate_data.csv')

# %%
key_list
# Out:
# ['Return.@xmlns',
#  'Return.@xmlns:xsi',
#  'Return.@xsi:schemaLocation',
#  'Return.@returnVersion',
#  'Return.ReturnHeader.@binaryAttachmentCnt',
#  'Return.ReturnHeader.ReturnTs',
#  'Return.ReturnHeader.TaxPeriodEndDt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmEIN',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.AddressLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.CityNm',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.ZIPCd',
#  'Return.ReturnHeader.ReturnTypeCd',
#  'Return.ReturnHeader.TaxPeriodBeginDt',
#  'Return.ReturnHeader.Filer.EIN',
#  'Return.ReturnHeader.Filer.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.Filer.BusinessNameControlTxt',
#  'Return.ReturnHeader.Filer.PhoneNum',
#  'Return.ReturnHeader.Filer.USAddress.AddressLine1Txt',
#  'Return.ReturnHeader.Filer.USAddress.CityNm',
#  'Return.ReturnHeader.Filer.USAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.Filer.USAddress.ZIPCd',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonNm',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonTitleTxt',
#  'Return.ReturnHeader.BusinessOfficerGrp.PhoneNum',
#  'Return.ReturnHeader.BusinessOfficerGrp.SignatureDt',
#  'Return.ReturnHeader.BusinessOfficerGrp.DiscussWithPaidPreparerInd',
#  'Return.ReturnHeader.PreparerPersonGrp.PreparerPersonNm',
#  'Return.ReturnHeader.PreparerPersonGrp.PTIN',
#  'Return.ReturnHeader.PreparerPersonGrp.PhoneNum',
#  'Return.ReturnHeader.FilingSecurityInformation.IPAddress.IPv4AddressTxt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPDt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTm',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTimezoneCd',
#  'Return.ReturnHeader.FilingSecurityInformation.FilingLicenseTypeCd',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionCreationDeviceId',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionFilingDeviceId',
#  'Return.ReturnHeader.TaxYr',
#  'Return.ReturnHeader.BuildTS',
#  'Return.ReturnData.@documentCnt',
#  'Return.ReturnData.IRS990.@documentId',
#  'Return.ReturnData.IRS990.@referenceDocumentId',
#  'Return.ReturnData.IRS990.PrincipalOfficerNm',
#  'Return.ReturnData.IRS990.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.USAddress.CityNm',
#  'Return.ReturnData.IRS990.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.GrossReceiptsAmt',
#  'Return.ReturnData.IRS990.GroupReturnForAffiliatesInd',
#  'Return.ReturnData.IRS990.Organization501c3Ind',
#  'Return.ReturnData.IRS990.WebsiteAddressTxt',
#  'Return.ReturnData.IRS990.TypeOfOrganizationCorpInd',
#  'Return.ReturnData.IRS990.FormationYr',
#  'Return.ReturnData.IRS990.LegalDomicileStateCd',
#  'Return.ReturnData.IRS990.ActivityOrMissionDesc',
#  'Return.ReturnData.IRS990.VotingMembersGoverningBodyCnt',
#  'Return.ReturnData.IRS990.VotingMembersIndependentCnt',
#  'Return.ReturnData.IRS990.TotalEmployeeCnt',
#  'Return.ReturnData.IRS990.TotalVolunteersCnt',
#  'Return.ReturnData.IRS990.TotalGrossUBIAmt',
#  'Return.ReturnData.IRS990.NetUnrelatedBusTxblIncmAmt',
#  'Return.ReturnData.IRS990.PYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.CYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.PYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.CYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.PYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.CYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.PYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.CYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.PYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.CYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.PYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.CYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.PYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.CYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.PYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.CYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.PYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalFundraisingExpenseAmt',
#  'Return.ReturnData.IRS990.PYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.CYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.PYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.CYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.PYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.CYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.TotalAssetsBOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsEOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesBOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesEOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesBOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesEOYAmt',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartIIIInd',
#  'Return.ReturnData.IRS990.MissionDesc',
#  'Return.ReturnData.IRS990.SignificantNewProgramSrvcInd',
#  'Return.ReturnData.IRS990.SignificantChangeInd',
#  'Return.ReturnData.IRS990.ExpenseAmt',
#  'Return.ReturnData.IRS990.GrantAmt',
#  'Return.ReturnData.IRS990.RevenueAmt',
#  'Return.ReturnData.IRS990.Desc',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.ExpenseAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.RevenueAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.Desc',
#  'Return.ReturnData.IRS990.TotalProgramServiceExpensesAmt',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.#text',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.#text',
#  'Return.ReturnData.IRS990.PoliticalCampaignActyInd',
#  'Return.ReturnData.IRS990.LobbyingActivitiesInd',
#  'Return.ReturnData.IRS990.SubjectToProxyTaxInd',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.#text',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.#text',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.#text',
#  'Return.ReturnData.IRS990.CreditCounselingInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CreditCounselingInd.#text',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.#text',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.#text',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.#text',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.#text',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.#text',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.SchoolOperatingInd',
#  'Return.ReturnData.IRS990.ForeignOfficeInd',
#  'Return.ReturnData.IRS990.ForeignActivitiesInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToOrgInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToIndividualsInd',
#  'Return.ReturnData.IRS990.ProfessionalFundraisingInd',
#  'Return.ReturnData.IRS990.FundraisingActivitiesInd',
#  'Return.ReturnData.IRS990.GamingActivitiesInd',
#  'Return.ReturnData.IRS990.OperateHospitalInd',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.#text',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.#text',
#  'Return.ReturnData.IRS990.ScheduleJRequiredInd',
#  'Return.ReturnData.IRS990.TaxExemptBondsInd',
#  'Return.ReturnData.IRS990.EngagedInExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.PYExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.LoanOutstandingInd',
#  'Return.ReturnData.IRS990.GrantToRelatedPersonInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOrgMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithFamMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOfficerEntInd',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.#text',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.#text',
#  'Return.ReturnData.IRS990.TerminateOperationsInd',
#  'Return.ReturnData.IRS990.PartialLiquidationInd',
#  'Return.ReturnData.IRS990.DisregardedEntityInd',
#  'Return.ReturnData.IRS990.RelatedEntityInd',
#  'Return.ReturnData.IRS990.RelatedOrganizationCtrlEntInd',
#  'Return.ReturnData.IRS990.TrnsfrExmptNonChrtblRltdOrgInd',
#  'Return.ReturnData.IRS990.ActivitiesConductedPrtshpInd',
#  'Return.ReturnData.IRS990.ScheduleORequiredInd',
#  'Return.ReturnData.IRS990.IRPDocumentCnt',
#  'Return.ReturnData.IRS990.IRPDocumentW2GCnt',
#  'Return.ReturnData.IRS990.BackupWthldComplianceInd',
#  'Return.ReturnData.IRS990.EmployeeCnt',
#  'Return.ReturnData.IRS990.UnrelatedBusIncmOverLimitInd',
#  'Return.ReturnData.IRS990.ForeignFinancialAccountInd',
#  'Return.ReturnData.IRS990.ProhibitedTaxShelterTransInd',
#  'Return.ReturnData.IRS990.TaxablePartyNotificationInd',
#  'Return.ReturnData.IRS990.NondeductibleContributionsInd',
#  'Return.ReturnData.IRS990.QuidProQuoContributionsInd',
#  'Return.ReturnData.IRS990.Form8282PropertyDisposedOfInd',
#  'Return.ReturnData.IRS990.RcvFndsToPayPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.PayPremiumsPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.IndoorTanningServicesInd',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartVIInd',
#  'Return.ReturnData.IRS990.GoverningBodyVotingMembersCnt',
#  'Return.ReturnData.IRS990.IndependentVotingMemberCnt',
#  'Return.ReturnData.IRS990.FamilyOrBusinessRlnInd',
#  'Return.ReturnData.IRS990.DelegationOfMgmtDutiesInd',
#  'Return.ReturnData.IRS990.ChangeToOrgDocumentsInd',
#  'Return.ReturnData.IRS990.MaterialDiversionOrMisuseInd',
#  'Return.ReturnData.IRS990.MembersOrStockholdersInd',
#  'Return.ReturnData.IRS990.ElectionOfBoardMembersInd',
#  'Return.ReturnData.IRS990.DecisionsSubjectToApprovaInd',
#  'Return.ReturnData.IRS990.MinutesOfGoverningBodyInd',
#  'Return.ReturnData.IRS990.MinutesOfCommitteesInd',
#  'Return.ReturnData.IRS990.OfficerMailingAddressInd',
#  'Return.ReturnData.IRS990.LocalChaptersInd',
#  'Return.ReturnData.IRS990.Form990ProvidedToGvrnBodyInd',
#  'Return.ReturnData.IRS990.ConflictOfInterestPolicyInd',
#  'Return.ReturnData.IRS990.AnnualDisclosureCoveredPrsnInd',
#  'Return.ReturnData.IRS990.RegularMonitoringEnfrcInd',
#  'Return.ReturnData.IRS990.WhistleblowerPolicyInd',
#  'Return.ReturnData.IRS990.DocumentRetentionPolicyInd',
#  'Return.ReturnData.IRS990.CompensationProcessCEOInd',
#  'Return.ReturnData.IRS990.CompensationProcessOtherInd',
#  'Return.ReturnData.IRS990.InvestmentInJointVentureInd',
#  'Return.ReturnData.IRS990.StatesWhereCopyOfReturnIsFldCd',
#  'Return.ReturnData.IRS990.OtherWebsiteInd',
#  'Return.ReturnData.IRS990.UponRequestInd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.PhoneNum',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.CityNm',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.PersonNm',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.TitleTxt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.AverageHoursPerWeekRt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.IndividualTrusteeOrDirectorInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OfficerInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromRltdOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OtherCompensationAmt',
#  'Return.ReturnData.IRS990.TotalReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.TotReportableCompRltdOrgAmt',
#  'Return.ReturnData.IRS990.TotalOtherCompensationAmt',
#  'Return.ReturnData.IRS990.IndivRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.FormerOfcrEmployeesListedInd',
#  'Return.ReturnData.IRS990.TotalCompGreaterThan150KInd',
#  'Return.ReturnData.IRS990.CompensationFromOtherSrcsInd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorName.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.CityNm',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ServicesDesc',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.CompensationAmt',
#  'Return.ReturnData.IRS990.CntrctRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.AllOtherContributionsAmt',
#  'Return.ReturnData.IRS990.NoncashContributionsAmt',
#  'Return.ReturnData.IRS990.TotalContributionsAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.Desc',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.BusinessCd',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.LessCostOthBasisSalesExpnssGrp.OtherAmt',
#  'Return.ReturnData.IRS990.GainOrLossGrp.OtherAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.Desc',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.BusinessCd',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueTotalAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.UnrelatedBusinessRevenueAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.TotalAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.TravelGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TravelGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InterestGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InterestGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.TotalAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.Desc',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.BOYAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.EOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.BOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.EOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipCostOrOtherBssAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipAccumDeprecAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.BOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.EOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.BOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.EOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OrganizationFollowsSFAS117Ind',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.ReconcilationRevenueExpnssAmt',
#  'Return.ReturnData.IRS990.NetUnrlzdGainsLossesInvstAmt',
#  'Return.ReturnData.IRS990.OtherChangesInNetAssetsAmt',
#  'Return.ReturnData.IRS990.MethodOfAccountingAccrualInd',
#  'Return.ReturnData.IRS990.AccountantCompileOrReviewInd',
#  'Return.ReturnData.IRS990.FSAuditedInd',
#  'Return.ReturnData.IRS990.FSAuditedBasisGrp.SeparateBasisFinclStmtInd',
#  'Return.ReturnData.IRS990.AuditCommitteeInd',
#  'Return.ReturnData.IRS990.FederalGrantAuditRequiredInd',
#  'Return.ReturnData.IRS990ScheduleA.@documentId',
#  'Return.ReturnData.IRS990ScheduleA.PublicOrganization170Ind',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.SubstantialContributorsTotAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportTotal170Amt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalSupportAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossReceiptsRltdActivitiesAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportCY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportPY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.ThirtyThrPctSuprtTestsCY170Ind',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleB.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueLandBuildingsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueOtherAssetsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotalLiabilityAmt',
#  'Return.ReturnData.IRS990ScheduleD.FootnoteTextInd',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.NetUnrealizedGainsInvstAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesAndUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherRevenueAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevenuePerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotExpnsEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherExpensesIncludedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotRptFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalExpensesPerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleI.@documentId',
#  'Return.ReturnData.IRS990ScheduleI.GrantRecordsMaintainedInd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientBusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.CityNm',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientEIN',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.IRCSectionDesc',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.CashGrantAmt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.PurposeOfGrantTxt',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleM.@documentId',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NonCashCheckboxInd',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.ContributionCnt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NoncashContributionsRptF990Amt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.MethodOfDeterminingRevenuesTxt',
#  'Return.ReturnData.IRS990ScheduleM.AnyPropertyThatMustBeHeldInd',
#  'Return.ReturnData.IRS990ScheduleM.ReviewProcessUnusualNCGiftsInd',
#  'Return.ReturnData.IRS990ScheduleM.ThirdPartiesUsedInd',
#  'Return.ReturnData.IRS990ScheduleO.@documentId',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.ExplanationTxt']
