# %%
import os, requests, re, time, numpy as np, pandas as pd, pickle
from IPython.display import clear_output

import xmltodict

# %%
def get_node_names(parent):
    node_names = []
    
    for item in parent.items():
        if item[1] != None:
            if type(item[1]) == str:
                node_names.append(item[0])
            
            elif type(item[1]) == list:
                try:
                    child_list_node_names = get_node_names(item[1][0])
                    for child in child_list_node_names:
                        string_name = item[0] + '.' + child
                        node_names.append(string_name)
                except AttributeError:
                    pass
            
            else:
                child_node_names = get_node_names(item[1])
                for child in child_node_names:
                    string_name = item[0] + '.' + child
                    node_names.append(string_name)
            
    return node_names

def get_node_values(parent):
    value_list = []
    for item in parent.items():
        if item[1] != None:
            if type(item[1]) == str:
                value_list.append(item[1])
            
            elif type(item[1]) == list:
                try:
                    child_values = get_node_values(item[1][0])
                    for value in child_values:
                        value_list.append(value)
                except AttributeError:
                    pass
            
            else:
                child_values = get_node_values(item[1])
                for value in child_values:
                    value_list.append(value)
    
    return value_list

# %%
monroe_html = 'https://s3.amazonaws.com/irs-form-990/201911159349300636_public.xml'
monroe_baseline = xmltodict.parse(requests.get(monroe_html).content)
monroe_node_list = get_node_names(monroe_baseline)
monroe_dictionary = dict(zip(monroe_node_list, get_node_values(monroe_baseline)))
key_list = list(monroe_dictionary.keys())

# %%
key_list
# Out:
# ['Return.@xmlns',
#  'Return.@xmlns:xsi',
#  'Return.@xsi:schemaLocation',
#  'Return.@returnVersion',
#  'Return.ReturnHeader.@binaryAttachmentCnt',
#  'Return.ReturnHeader.ReturnTs',
#  'Return.ReturnHeader.TaxPeriodEndDt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmEIN',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.AddressLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.CityNm',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.ZIPCd',
#  'Return.ReturnHeader.ReturnTypeCd',
#  'Return.ReturnHeader.TaxPeriodBeginDt',
#  'Return.ReturnHeader.Filer.EIN',
#  'Return.ReturnHeader.Filer.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.Filer.BusinessNameControlTxt',
#  'Return.ReturnHeader.Filer.PhoneNum',
#  'Return.ReturnHeader.Filer.USAddress.AddressLine1Txt',
#  'Return.ReturnHeader.Filer.USAddress.CityNm',
#  'Return.ReturnHeader.Filer.USAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.Filer.USAddress.ZIPCd',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonNm',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonTitleTxt',
#  'Return.ReturnHeader.BusinessOfficerGrp.PhoneNum',
#  'Return.ReturnHeader.BusinessOfficerGrp.SignatureDt',
#  'Return.ReturnHeader.BusinessOfficerGrp.DiscussWithPaidPreparerInd',
#  'Return.ReturnHeader.PreparerPersonGrp.PreparerPersonNm',
#  'Return.ReturnHeader.PreparerPersonGrp.PTIN',
#  'Return.ReturnHeader.PreparerPersonGrp.PhoneNum',
#  'Return.ReturnHeader.FilingSecurityInformation.IPAddress.IPv4AddressTxt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPDt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTm',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTimezoneCd',
#  'Return.ReturnHeader.FilingSecurityInformation.FilingLicenseTypeCd',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionCreationDeviceId',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionFilingDeviceId',
#  'Return.ReturnHeader.TaxYr',
#  'Return.ReturnHeader.BuildTS',
#  'Return.ReturnData.@documentCnt',
#  'Return.ReturnData.IRS990.@documentId',
#  'Return.ReturnData.IRS990.@referenceDocumentId',
#  'Return.ReturnData.IRS990.PrincipalOfficerNm',
#  'Return.ReturnData.IRS990.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.USAddress.CityNm',
#  'Return.ReturnData.IRS990.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.GrossReceiptsAmt',
#  'Return.ReturnData.IRS990.GroupReturnForAffiliatesInd',
#  'Return.ReturnData.IRS990.Organization501c3Ind',
#  'Return.ReturnData.IRS990.WebsiteAddressTxt',
#  'Return.ReturnData.IRS990.TypeOfOrganizationCorpInd',
#  'Return.ReturnData.IRS990.FormationYr',
#  'Return.ReturnData.IRS990.LegalDomicileStateCd',
#  'Return.ReturnData.IRS990.ActivityOrMissionDesc',
#  'Return.ReturnData.IRS990.VotingMembersGoverningBodyCnt',
#  'Return.ReturnData.IRS990.VotingMembersIndependentCnt',
#  'Return.ReturnData.IRS990.TotalEmployeeCnt',
#  'Return.ReturnData.IRS990.TotalVolunteersCnt',
#  'Return.ReturnData.IRS990.TotalGrossUBIAmt',
#  'Return.ReturnData.IRS990.NetUnrelatedBusTxblIncmAmt',
#  'Return.ReturnData.IRS990.PYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.CYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.PYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.CYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.PYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.CYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.PYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.CYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.PYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.CYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.PYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.CYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.PYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.CYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.PYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.CYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.PYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalFundraisingExpenseAmt',
#  'Return.ReturnData.IRS990.PYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.CYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.PYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.CYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.PYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.CYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.TotalAssetsBOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsEOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesBOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesEOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesBOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesEOYAmt',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartIIIInd',
#  'Return.ReturnData.IRS990.MissionDesc',
#  'Return.ReturnData.IRS990.SignificantNewProgramSrvcInd',
#  'Return.ReturnData.IRS990.SignificantChangeInd',
#  'Return.ReturnData.IRS990.ExpenseAmt',
#  'Return.ReturnData.IRS990.GrantAmt',
#  'Return.ReturnData.IRS990.RevenueAmt',
#  'Return.ReturnData.IRS990.Desc',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.ExpenseAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.RevenueAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.Desc',
#  'Return.ReturnData.IRS990.TotalProgramServiceExpensesAmt',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.#text',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.#text',
#  'Return.ReturnData.IRS990.PoliticalCampaignActyInd',
#  'Return.ReturnData.IRS990.LobbyingActivitiesInd',
#  'Return.ReturnData.IRS990.SubjectToProxyTaxInd',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.#text',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.#text',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.#text',
#  'Return.ReturnData.IRS990.CreditCounselingInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CreditCounselingInd.#text',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.#text',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.#text',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.#text',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.#text',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.#text',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.SchoolOperatingInd',
#  'Return.ReturnData.IRS990.ForeignOfficeInd',
#  'Return.ReturnData.IRS990.ForeignActivitiesInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToOrgInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToIndividualsInd',
#  'Return.ReturnData.IRS990.ProfessionalFundraisingInd',
#  'Return.ReturnData.IRS990.FundraisingActivitiesInd',
#  'Return.ReturnData.IRS990.GamingActivitiesInd',
#  'Return.ReturnData.IRS990.OperateHospitalInd',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.#text',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.#text',
#  'Return.ReturnData.IRS990.ScheduleJRequiredInd',
#  'Return.ReturnData.IRS990.TaxExemptBondsInd',
#  'Return.ReturnData.IRS990.EngagedInExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.PYExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.LoanOutstandingInd',
#  'Return.ReturnData.IRS990.GrantToRelatedPersonInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOrgMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithFamMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOfficerEntInd',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.#text',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.#text',
#  'Return.ReturnData.IRS990.TerminateOperationsInd',
#  'Return.ReturnData.IRS990.PartialLiquidationInd',
#  'Return.ReturnData.IRS990.DisregardedEntityInd',
#  'Return.ReturnData.IRS990.RelatedEntityInd',
#  'Return.ReturnData.IRS990.RelatedOrganizationCtrlEntInd',
#  'Return.ReturnData.IRS990.TrnsfrExmptNonChrtblRltdOrgInd',
#  'Return.ReturnData.IRS990.ActivitiesConductedPrtshpInd',
#  'Return.ReturnData.IRS990.ScheduleORequiredInd',
#  'Return.ReturnData.IRS990.IRPDocumentCnt',
#  'Return.ReturnData.IRS990.IRPDocumentW2GCnt',
#  'Return.ReturnData.IRS990.BackupWthldComplianceInd',
#  'Return.ReturnData.IRS990.EmployeeCnt',
#  'Return.ReturnData.IRS990.UnrelatedBusIncmOverLimitInd',
#  'Return.ReturnData.IRS990.ForeignFinancialAccountInd',
#  'Return.ReturnData.IRS990.ProhibitedTaxShelterTransInd',
#  'Return.ReturnData.IRS990.TaxablePartyNotificationInd',
#  'Return.ReturnData.IRS990.NondeductibleContributionsInd',
#  'Return.ReturnData.IRS990.QuidProQuoContributionsInd',
#  'Return.ReturnData.IRS990.Form8282PropertyDisposedOfInd',
#  'Return.ReturnData.IRS990.RcvFndsToPayPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.PayPremiumsPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.IndoorTanningServicesInd',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartVIInd',
#  'Return.ReturnData.IRS990.GoverningBodyVotingMembersCnt',
#  'Return.ReturnData.IRS990.IndependentVotingMemberCnt',
#  'Return.ReturnData.IRS990.FamilyOrBusinessRlnInd',
#  'Return.ReturnData.IRS990.DelegationOfMgmtDutiesInd',
#  'Return.ReturnData.IRS990.ChangeToOrgDocumentsInd',
#  'Return.ReturnData.IRS990.MaterialDiversionOrMisuseInd',
#  'Return.ReturnData.IRS990.MembersOrStockholdersInd',
#  'Return.ReturnData.IRS990.ElectionOfBoardMembersInd',
#  'Return.ReturnData.IRS990.DecisionsSubjectToApprovaInd',
#  'Return.ReturnData.IRS990.MinutesOfGoverningBodyInd',
#  'Return.ReturnData.IRS990.MinutesOfCommitteesInd',
#  'Return.ReturnData.IRS990.OfficerMailingAddressInd',
#  'Return.ReturnData.IRS990.LocalChaptersInd',
#  'Return.ReturnData.IRS990.Form990ProvidedToGvrnBodyInd',
#  'Return.ReturnData.IRS990.ConflictOfInterestPolicyInd',
#  'Return.ReturnData.IRS990.AnnualDisclosureCoveredPrsnInd',
#  'Return.ReturnData.IRS990.RegularMonitoringEnfrcInd',
#  'Return.ReturnData.IRS990.WhistleblowerPolicyInd',
#  'Return.ReturnData.IRS990.DocumentRetentionPolicyInd',
#  'Return.ReturnData.IRS990.CompensationProcessCEOInd',
#  'Return.ReturnData.IRS990.CompensationProcessOtherInd',
#  'Return.ReturnData.IRS990.InvestmentInJointVentureInd',
#  'Return.ReturnData.IRS990.StatesWhereCopyOfReturnIsFldCd',
#  'Return.ReturnData.IRS990.OtherWebsiteInd',
#  'Return.ReturnData.IRS990.UponRequestInd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.PhoneNum',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.CityNm',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.PersonNm',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.TitleTxt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.AverageHoursPerWeekRt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.IndividualTrusteeOrDirectorInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OfficerInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromRltdOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OtherCompensationAmt',
#  'Return.ReturnData.IRS990.TotalReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.TotReportableCompRltdOrgAmt',
#  'Return.ReturnData.IRS990.TotalOtherCompensationAmt',
#  'Return.ReturnData.IRS990.IndivRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.FormerOfcrEmployeesListedInd',
#  'Return.ReturnData.IRS990.TotalCompGreaterThan150KInd',
#  'Return.ReturnData.IRS990.CompensationFromOtherSrcsInd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorName.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.CityNm',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ServicesDesc',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.CompensationAmt',
#  'Return.ReturnData.IRS990.CntrctRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.AllOtherContributionsAmt',
#  'Return.ReturnData.IRS990.NoncashContributionsAmt',
#  'Return.ReturnData.IRS990.TotalContributionsAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.Desc',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.BusinessCd',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.LessCostOthBasisSalesExpnssGrp.OtherAmt',
#  'Return.ReturnData.IRS990.GainOrLossGrp.OtherAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.Desc',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.BusinessCd',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueTotalAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.UnrelatedBusinessRevenueAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.TotalAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.TravelGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TravelGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InterestGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InterestGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.TotalAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.Desc',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.BOYAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.EOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.BOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.EOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipCostOrOtherBssAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipAccumDeprecAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.BOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.EOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.BOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.EOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OrganizationFollowsSFAS117Ind',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.ReconcilationRevenueExpnssAmt',
#  'Return.ReturnData.IRS990.NetUnrlzdGainsLossesInvstAmt',
#  'Return.ReturnData.IRS990.OtherChangesInNetAssetsAmt',
#  'Return.ReturnData.IRS990.MethodOfAccountingAccrualInd',
#  'Return.ReturnData.IRS990.AccountantCompileOrReviewInd',
#  'Return.ReturnData.IRS990.FSAuditedInd',
#  'Return.ReturnData.IRS990.FSAuditedBasisGrp.SeparateBasisFinclStmtInd',
#  'Return.ReturnData.IRS990.AuditCommitteeInd',
#  'Return.ReturnData.IRS990.FederalGrantAuditRequiredInd',
#  'Return.ReturnData.IRS990ScheduleA.@documentId',
#  'Return.ReturnData.IRS990ScheduleA.PublicOrganization170Ind',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.SubstantialContributorsTotAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportTotal170Amt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalSupportAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossReceiptsRltdActivitiesAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportCY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportPY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.ThirtyThrPctSuprtTestsCY170Ind',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleB.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueLandBuildingsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueOtherAssetsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotalLiabilityAmt',
#  'Return.ReturnData.IRS990ScheduleD.FootnoteTextInd',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.NetUnrealizedGainsInvstAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesAndUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherRevenueAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevenuePerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotExpnsEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherExpensesIncludedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotRptFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalExpensesPerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleI.@documentId',
#  'Return.ReturnData.IRS990ScheduleI.GrantRecordsMaintainedInd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientBusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.CityNm',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientEIN',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.IRCSectionDesc',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.CashGrantAmt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.PurposeOfGrantTxt',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleM.@documentId',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NonCashCheckboxInd',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.ContributionCnt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NoncashContributionsRptF990Amt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.MethodOfDeterminingRevenuesTxt',
#  'Return.ReturnData.IRS990ScheduleM.AnyPropertyThatMustBeHeldInd',
#  'Return.ReturnData.IRS990ScheduleM.ReviewProcessUnusualNCGiftsInd',
#  'Return.ReturnData.IRS990ScheduleM.ThirdPartiesUsedInd',
#  'Return.ReturnData.IRS990ScheduleO.@documentId',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.ExplanationTxt']

# %%
lasttext = []
for key in key_list:
    splitlist = key.rsplit('.')
    lasttext.append(splitlist[-1])

# %%
lasttext
# Out:
# ['@xmlns',
#  '@xmlns:xsi',
#  '@xsi:schemaLocation',
#  '@returnVersion',
#  '@binaryAttachmentCnt',
#  'ReturnTs',
#  'TaxPeriodEndDt',
#  'PreparerFirmEIN',
#  'BusinessNameLine1Txt',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'ReturnTypeCd',
#  'TaxPeriodBeginDt',
#  'EIN',
#  'BusinessNameLine1Txt',
#  'BusinessNameControlTxt',
#  'PhoneNum',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'PersonNm',
#  'PersonTitleTxt',
#  'PhoneNum',
#  'SignatureDt',
#  'DiscussWithPaidPreparerInd',
#  'PreparerPersonNm',
#  'PTIN',
#  'PhoneNum',
#  'IPv4AddressTxt',
#  'IPDt',
#  'IPTm',
#  'IPTimezoneCd',
#  'FilingLicenseTypeCd',
#  'AtSubmissionCreationDeviceId',
#  'AtSubmissionFilingDeviceId',
#  'TaxYr',
#  'BuildTS',
#  '@documentCnt',
#  '@documentId',
#  '@referenceDocumentId',
#  'PrincipalOfficerNm',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'GrossReceiptsAmt',
#  'GroupReturnForAffiliatesInd',
#  'Organization501c3Ind',
#  'WebsiteAddressTxt',
#  'TypeOfOrganizationCorpInd',
#  'FormationYr',
#  'LegalDomicileStateCd',
#  'ActivityOrMissionDesc',
#  'VotingMembersGoverningBodyCnt',
#  'VotingMembersIndependentCnt',
#  'TotalEmployeeCnt',
#  'TotalVolunteersCnt',
#  'TotalGrossUBIAmt',
#  'NetUnrelatedBusTxblIncmAmt',
#  'PYContributionsGrantsAmt',
#  'CYContributionsGrantsAmt',
#  'PYProgramServiceRevenueAmt',
#  'CYProgramServiceRevenueAmt',
#  'PYInvestmentIncomeAmt',
#  'CYInvestmentIncomeAmt',
#  'PYOtherRevenueAmt',
#  'CYOtherRevenueAmt',
#  'PYTotalRevenueAmt',
#  'CYTotalRevenueAmt',
#  'PYGrantsAndSimilarPaidAmt',
#  'CYGrantsAndSimilarPaidAmt',
#  'PYBenefitsPaidToMembersAmt',
#  'CYBenefitsPaidToMembersAmt',
#  'PYSalariesCompEmpBnftPaidAmt',
#  'CYSalariesCompEmpBnftPaidAmt',
#  'PYTotalProfFndrsngExpnsAmt',
#  'CYTotalProfFndrsngExpnsAmt',
#  'CYTotalFundraisingExpenseAmt',
#  'PYOtherExpensesAmt',
#  'CYOtherExpensesAmt',
#  'PYTotalExpensesAmt',
#  'CYTotalExpensesAmt',
#  'PYRevenuesLessExpensesAmt',
#  'CYRevenuesLessExpensesAmt',
#  'TotalAssetsBOYAmt',
#  'TotalAssetsEOYAmt',
#  'TotalLiabilitiesBOYAmt',
#  'TotalLiabilitiesEOYAmt',
#  'NetAssetsOrFundBalancesBOYAmt',
#  'NetAssetsOrFundBalancesEOYAmt',
#  'InfoInScheduleOPartIIIInd',
#  'MissionDesc',
#  'SignificantNewProgramSrvcInd',
#  'SignificantChangeInd',
#  'ExpenseAmt',
#  'GrantAmt',
#  'RevenueAmt',
#  'Desc',
#  'ExpenseAmt',
#  'RevenueAmt',
#  'Desc',
#  'TotalProgramServiceExpensesAmt',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  'PoliticalCampaignActyInd',
#  'LobbyingActivitiesInd',
#  'SubjectToProxyTaxInd',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  'SchoolOperatingInd',
#  'ForeignOfficeInd',
#  'ForeignActivitiesInd',
#  'MoreThan5000KToOrgInd',
#  'MoreThan5000KToIndividualsInd',
#  'ProfessionalFundraisingInd',
#  'FundraisingActivitiesInd',
#  'GamingActivitiesInd',
#  'OperateHospitalInd',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  'ScheduleJRequiredInd',
#  'TaxExemptBondsInd',
#  'EngagedInExcessBenefitTransInd',
#  'PYExcessBenefitTransInd',
#  'LoanOutstandingInd',
#  'GrantToRelatedPersonInd',
#  'BusinessRlnWithOrgMemInd',
#  'BusinessRlnWithFamMemInd',
#  'BusinessRlnWithOfficerEntInd',
#  '@referenceDocumentId',
#  '#text',
#  '@referenceDocumentId',
#  '#text',
#  'TerminateOperationsInd',
#  'PartialLiquidationInd',
#  'DisregardedEntityInd',
#  'RelatedEntityInd',
#  'RelatedOrganizationCtrlEntInd',
#  'TrnsfrExmptNonChrtblRltdOrgInd',
#  'ActivitiesConductedPrtshpInd',
#  'ScheduleORequiredInd',
#  'IRPDocumentCnt',
#  'IRPDocumentW2GCnt',
#  'BackupWthldComplianceInd',
#  'EmployeeCnt',
#  'UnrelatedBusIncmOverLimitInd',
#  'ForeignFinancialAccountInd',
#  'ProhibitedTaxShelterTransInd',
#  'TaxablePartyNotificationInd',
#  'NondeductibleContributionsInd',
#  'QuidProQuoContributionsInd',
#  'Form8282PropertyDisposedOfInd',
#  'RcvFndsToPayPrsnlBnftCntrctInd',
#  'PayPremiumsPrsnlBnftCntrctInd',
#  'IndoorTanningServicesInd',
#  'InfoInScheduleOPartVIInd',
#  'GoverningBodyVotingMembersCnt',
#  'IndependentVotingMemberCnt',
#  'FamilyOrBusinessRlnInd',
#  'DelegationOfMgmtDutiesInd',
#  'ChangeToOrgDocumentsInd',
#  'MaterialDiversionOrMisuseInd',
#  'MembersOrStockholdersInd',
#  'ElectionOfBoardMembersInd',
#  'DecisionsSubjectToApprovaInd',
#  'MinutesOfGoverningBodyInd',
#  'MinutesOfCommitteesInd',
#  'OfficerMailingAddressInd',
#  'LocalChaptersInd',
#  'Form990ProvidedToGvrnBodyInd',
#  'ConflictOfInterestPolicyInd',
#  'AnnualDisclosureCoveredPrsnInd',
#  'RegularMonitoringEnfrcInd',
#  'WhistleblowerPolicyInd',
#  'DocumentRetentionPolicyInd',
#  'CompensationProcessCEOInd',
#  'CompensationProcessOtherInd',
#  'InvestmentInJointVentureInd',
#  'StatesWhereCopyOfReturnIsFldCd',
#  'OtherWebsiteInd',
#  'UponRequestInd',
#  'BusinessNameLine1Txt',
#  'PhoneNum',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'PersonNm',
#  'TitleTxt',
#  'AverageHoursPerWeekRt',
#  'IndividualTrusteeOrDirectorInd',
#  'OfficerInd',
#  'ReportableCompFromOrgAmt',
#  'ReportableCompFromRltdOrgAmt',
#  'OtherCompensationAmt',
#  'TotalReportableCompFromOrgAmt',
#  'TotReportableCompRltdOrgAmt',
#  'TotalOtherCompensationAmt',
#  'IndivRcvdGreaterThan100KCnt',
#  'FormerOfcrEmployeesListedInd',
#  'TotalCompGreaterThan150KInd',
#  'CompensationFromOtherSrcsInd',
#  'BusinessNameLine1Txt',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'ServicesDesc',
#  'CompensationAmt',
#  'CntrctRcvdGreaterThan100KCnt',
#  'AllOtherContributionsAmt',
#  'NoncashContributionsAmt',
#  'TotalContributionsAmt',
#  'Desc',
#  'BusinessCd',
#  'TotalRevenueColumnAmt',
#  'RelatedOrExemptFuncIncomeAmt',
#  'TotalProgramServiceRevenueAmt',
#  'TotalRevenueColumnAmt',
#  'ExclusionAmt',
#  'OtherAmt',
#  'OtherAmt',
#  'TotalRevenueColumnAmt',
#  'ExclusionAmt',
#  'Desc',
#  'BusinessCd',
#  'TotalRevenueColumnAmt',
#  'ExclusionAmt',
#  'OtherRevenueTotalAmt',
#  'TotalRevenueColumnAmt',
#  'RelatedOrExemptFuncIncomeAmt',
#  'UnrelatedBusinessRevenueAmt',
#  'ExclusionAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'Desc',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'TotalAmt',
#  'ProgramServicesAmt',
#  'ManagementAndGeneralAmt',
#  'FundraisingAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'LandBldgEquipCostOrOtherBssAmt',
#  'LandBldgEquipAccumDeprecAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'OrganizationFollowsSFAS117Ind',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'BOYAmt',
#  'EOYAmt',
#  'ReconcilationRevenueExpnssAmt',
#  'NetUnrlzdGainsLossesInvstAmt',
#  'OtherChangesInNetAssetsAmt',
#  'MethodOfAccountingAccrualInd',
#  'AccountantCompileOrReviewInd',
#  'FSAuditedInd',
#  'SeparateBasisFinclStmtInd',
#  'AuditCommitteeInd',
#  'FederalGrantAuditRequiredInd',
#  '@documentId',
#  'PublicOrganization170Ind',
#  'CurrentTaxYearMinus4YearsAmt',
#  'CurrentTaxYearMinus3YearsAmt',
#  'CurrentTaxYearMinus2YearsAmt',
#  'CurrentTaxYearMinus1YearAmt',
#  'CurrentTaxYearAmt',
#  'TotalAmt',
#  'CurrentTaxYearMinus4YearsAmt',
#  'CurrentTaxYearMinus3YearsAmt',
#  'CurrentTaxYearMinus2YearsAmt',
#  'CurrentTaxYearMinus1YearAmt',
#  'CurrentTaxYearAmt',
#  'TotalAmt',
#  'SubstantialContributorsTotAmt',
#  'PublicSupportTotal170Amt',
#  'CurrentTaxYearMinus4YearsAmt',
#  'CurrentTaxYearMinus3YearsAmt',
#  'CurrentTaxYearMinus2YearsAmt',
#  'CurrentTaxYearMinus1YearAmt',
#  'CurrentTaxYearAmt',
#  'TotalAmt',
#  'CurrentTaxYearMinus4YearsAmt',
#  'CurrentTaxYearMinus3YearsAmt',
#  'CurrentTaxYearMinus2YearsAmt',
#  'CurrentTaxYearMinus1YearAmt',
#  'CurrentTaxYearAmt',
#  'TotalAmt',
#  'TotalSupportAmt',
#  'GrossReceiptsRltdActivitiesAmt',
#  'PublicSupportCY170Pct',
#  'PublicSupportPY170Pct',
#  'ThirtyThrPctSuprtTestsCY170Ind',
#  'FormAndLineReferenceDesc',
#  'ExplanationTxt',
#  '@documentId',
#  '@documentId',
#  'OtherCostOrOtherBasisAmt',
#  'DepreciationAmt',
#  'BookValueAmt',
#  'OtherCostOrOtherBasisAmt',
#  'DepreciationAmt',
#  'BookValueAmt',
#  'OtherCostOrOtherBasisAmt',
#  'DepreciationAmt',
#  'BookValueAmt',
#  'TotalBookValueLandBuildingsAmt',
#  'Desc',
#  'BookValueAmt',
#  'TotalBookValueOtherAssetsAmt',
#  'Desc',
#  'Amt',
#  'TotalLiabilityAmt',
#  'FootnoteTextInd',
#  'TotalRevEtcAuditedFinclStmtAmt',
#  'NetUnrealizedGainsInvstAmt',
#  'DonatedServicesAndUseFcltsAmt',
#  'OtherRevenueAmt',
#  'RevenueNotReportedAmt',
#  'RevenueSubtotalAmt',
#  'RevenueNotReportedFinclStmtAmt',
#  'TotalRevenuePerForm990Amt',
#  'TotExpnsEtcAuditedFinclStmtAmt',
#  'DonatedServicesUseFcltsAmt',
#  'OtherExpensesIncludedAmt',
#  'ExpensesNotReportedAmt',
#  'ExpensesSubtotalAmt',
#  'ExpensesNotRptFinclStmtAmt',
#  'TotalExpensesPerForm990Amt',
#  'FormAndLineReferenceDesc',
#  'ExplanationTxt',
#  '@documentId',
#  'GrantRecordsMaintainedInd',
#  'BusinessNameLine1Txt',
#  'AddressLine1Txt',
#  'CityNm',
#  'StateAbbreviationCd',
#  'ZIPCd',
#  'RecipientEIN',
#  'IRCSectionDesc',
#  'CashGrantAmt',
#  'PurposeOfGrantTxt',
#  'FormAndLineReferenceDesc',
#  'ExplanationTxt',
#  '@documentId',
#  'NonCashCheckboxInd',
#  'ContributionCnt',
#  'NoncashContributionsRptF990Amt',
#  'MethodOfDeterminingRevenuesTxt',
#  'AnyPropertyThatMustBeHeldInd',
#  'ReviewProcessUnusualNCGiftsInd',
#  'ThirdPartiesUsedInd',
#  '@documentId',
#  'FormAndLineReferenceDesc',
#  'ExplanationTxt']

# %%
def duplicates(lst):
    observed = set()
    observed_add = observed.add
    duplicate = set(x for x in lst if x in observed or observed_add(x))
    return list(duplicate)

# %%
duplicates(lasttext)
# Out:
# ['ExpenseAmt',
#  'DepreciationAmt',
#  'ManagementAndGeneralAmt',
#  'FormAndLineReferenceDesc',
#  'CurrentTaxYearMinus4YearsAmt',
#  'BOYAmt',
#  'BookValueAmt',
#  'PhoneNum',
#  'CurrentTaxYearMinus2YearsAmt',
#  'ExclusionAmt',
#  'RevenueAmt',
#  'TotalRevenueColumnAmt',
#  'RelatedOrExemptFuncIncomeAmt',
#  '@referenceDocumentId',
#  'EOYAmt',
#  'CurrentTaxYearMinus3YearsAmt',
#  'TotalAmt',
#  'StateAbbreviationCd',
#  'OtherAmt',
#  'CurrentTaxYearMinus1YearAmt',
#  'FundraisingAmt',
#  '#text',
#  'ZIPCd',
#  'CityNm',
#  'ExplanationTxt',
#  'PersonNm',
#  'CurrentTaxYearAmt',
#  'ProgramServicesAmt',
#  'OtherCostOrOtherBasisAmt',
#  'AddressLine1Txt',
#  '@documentId',
#  'Desc',
#  'BusinessCd',
#  'BusinessNameLine1Txt']

# %%
key_list
# Out:
# ['Return.@xmlns',
#  'Return.@xmlns:xsi',
#  'Return.@xsi:schemaLocation',
#  'Return.@returnVersion',
#  'Return.ReturnHeader.@binaryAttachmentCnt',
#  'Return.ReturnHeader.ReturnTs',
#  'Return.ReturnHeader.TaxPeriodEndDt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmEIN',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerFirmName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.AddressLine1Txt',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.CityNm',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.PreparerFirmGrp.PreparerUSAddress.ZIPCd',
#  'Return.ReturnHeader.ReturnTypeCd',
#  'Return.ReturnHeader.TaxPeriodBeginDt',
#  'Return.ReturnHeader.Filer.EIN',
#  'Return.ReturnHeader.Filer.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnHeader.Filer.BusinessNameControlTxt',
#  'Return.ReturnHeader.Filer.PhoneNum',
#  'Return.ReturnHeader.Filer.USAddress.AddressLine1Txt',
#  'Return.ReturnHeader.Filer.USAddress.CityNm',
#  'Return.ReturnHeader.Filer.USAddress.StateAbbreviationCd',
#  'Return.ReturnHeader.Filer.USAddress.ZIPCd',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonNm',
#  'Return.ReturnHeader.BusinessOfficerGrp.PersonTitleTxt',
#  'Return.ReturnHeader.BusinessOfficerGrp.PhoneNum',
#  'Return.ReturnHeader.BusinessOfficerGrp.SignatureDt',
#  'Return.ReturnHeader.BusinessOfficerGrp.DiscussWithPaidPreparerInd',
#  'Return.ReturnHeader.PreparerPersonGrp.PreparerPersonNm',
#  'Return.ReturnHeader.PreparerPersonGrp.PTIN',
#  'Return.ReturnHeader.PreparerPersonGrp.PhoneNum',
#  'Return.ReturnHeader.FilingSecurityInformation.IPAddress.IPv4AddressTxt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPDt',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTm',
#  'Return.ReturnHeader.FilingSecurityInformation.IPTimezoneCd',
#  'Return.ReturnHeader.FilingSecurityInformation.FilingLicenseTypeCd',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionCreationDeviceId',
#  'Return.ReturnHeader.FilingSecurityInformation.AtSubmissionFilingDeviceId',
#  'Return.ReturnHeader.TaxYr',
#  'Return.ReturnHeader.BuildTS',
#  'Return.ReturnData.@documentCnt',
#  'Return.ReturnData.IRS990.@documentId',
#  'Return.ReturnData.IRS990.@referenceDocumentId',
#  'Return.ReturnData.IRS990.PrincipalOfficerNm',
#  'Return.ReturnData.IRS990.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.USAddress.CityNm',
#  'Return.ReturnData.IRS990.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.GrossReceiptsAmt',
#  'Return.ReturnData.IRS990.GroupReturnForAffiliatesInd',
#  'Return.ReturnData.IRS990.Organization501c3Ind',
#  'Return.ReturnData.IRS990.WebsiteAddressTxt',
#  'Return.ReturnData.IRS990.TypeOfOrganizationCorpInd',
#  'Return.ReturnData.IRS990.FormationYr',
#  'Return.ReturnData.IRS990.LegalDomicileStateCd',
#  'Return.ReturnData.IRS990.ActivityOrMissionDesc',
#  'Return.ReturnData.IRS990.VotingMembersGoverningBodyCnt',
#  'Return.ReturnData.IRS990.VotingMembersIndependentCnt',
#  'Return.ReturnData.IRS990.TotalEmployeeCnt',
#  'Return.ReturnData.IRS990.TotalVolunteersCnt',
#  'Return.ReturnData.IRS990.TotalGrossUBIAmt',
#  'Return.ReturnData.IRS990.NetUnrelatedBusTxblIncmAmt',
#  'Return.ReturnData.IRS990.PYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.CYContributionsGrantsAmt',
#  'Return.ReturnData.IRS990.PYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.CYProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.PYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.CYInvestmentIncomeAmt',
#  'Return.ReturnData.IRS990.PYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.CYOtherRevenueAmt',
#  'Return.ReturnData.IRS990.PYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.CYTotalRevenueAmt',
#  'Return.ReturnData.IRS990.PYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.CYGrantsAndSimilarPaidAmt',
#  'Return.ReturnData.IRS990.PYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.CYBenefitsPaidToMembersAmt',
#  'Return.ReturnData.IRS990.PYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.CYSalariesCompEmpBnftPaidAmt',
#  'Return.ReturnData.IRS990.PYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalProfFndrsngExpnsAmt',
#  'Return.ReturnData.IRS990.CYTotalFundraisingExpenseAmt',
#  'Return.ReturnData.IRS990.PYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.CYOtherExpensesAmt',
#  'Return.ReturnData.IRS990.PYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.CYTotalExpensesAmt',
#  'Return.ReturnData.IRS990.PYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.CYRevenuesLessExpensesAmt',
#  'Return.ReturnData.IRS990.TotalAssetsBOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsEOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesBOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesEOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesBOYAmt',
#  'Return.ReturnData.IRS990.NetAssetsOrFundBalancesEOYAmt',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartIIIInd',
#  'Return.ReturnData.IRS990.MissionDesc',
#  'Return.ReturnData.IRS990.SignificantNewProgramSrvcInd',
#  'Return.ReturnData.IRS990.SignificantChangeInd',
#  'Return.ReturnData.IRS990.ExpenseAmt',
#  'Return.ReturnData.IRS990.GrantAmt',
#  'Return.ReturnData.IRS990.RevenueAmt',
#  'Return.ReturnData.IRS990.Desc',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.ExpenseAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.RevenueAmt',
#  'Return.ReturnData.IRS990.ProgSrvcAccomActy2Grp.Desc',
#  'Return.ReturnData.IRS990.TotalProgramServiceExpensesAmt',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DescribedInSection501c3Ind.#text',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ScheduleBRequiredInd.#text',
#  'Return.ReturnData.IRS990.PoliticalCampaignActyInd',
#  'Return.ReturnData.IRS990.LobbyingActivitiesInd',
#  'Return.ReturnData.IRS990.SubjectToProxyTaxInd',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DonorAdvisedFundInd.#text',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConservationEasementsInd.#text',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CollectionsOfArtInd.#text',
#  'Return.ReturnData.IRS990.CreditCounselingInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.CreditCounselingInd.#text',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.TempOrPermanentEndowmentsInd.#text',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportLandBuildingEquipmentInd.#text',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportInvestmentsOtherSecInd.#text',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportProgramRelatedInvstInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherAssetsInd.#text',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ReportOtherLiabilitiesInd.#text',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IncludeFIN48FootnoteInd.#text',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.IndependentAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.ConsolidatedAuditFinclStmtInd.#text',
#  'Return.ReturnData.IRS990.SchoolOperatingInd',
#  'Return.ReturnData.IRS990.ForeignOfficeInd',
#  'Return.ReturnData.IRS990.ForeignActivitiesInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToOrgInd',
#  'Return.ReturnData.IRS990.MoreThan5000KToIndividualsInd',
#  'Return.ReturnData.IRS990.ProfessionalFundraisingInd',
#  'Return.ReturnData.IRS990.FundraisingActivitiesInd',
#  'Return.ReturnData.IRS990.GamingActivitiesInd',
#  'Return.ReturnData.IRS990.OperateHospitalInd',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToOrganizationsInd.#text',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.GrantsToIndividualsInd.#text',
#  'Return.ReturnData.IRS990.ScheduleJRequiredInd',
#  'Return.ReturnData.IRS990.TaxExemptBondsInd',
#  'Return.ReturnData.IRS990.EngagedInExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.PYExcessBenefitTransInd',
#  'Return.ReturnData.IRS990.LoanOutstandingInd',
#  'Return.ReturnData.IRS990.GrantToRelatedPersonInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOrgMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithFamMemInd',
#  'Return.ReturnData.IRS990.BusinessRlnWithOfficerEntInd',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleNonCashContriInd.#text',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.@referenceDocumentId',
#  'Return.ReturnData.IRS990.DeductibleArtContributionInd.#text',
#  'Return.ReturnData.IRS990.TerminateOperationsInd',
#  'Return.ReturnData.IRS990.PartialLiquidationInd',
#  'Return.ReturnData.IRS990.DisregardedEntityInd',
#  'Return.ReturnData.IRS990.RelatedEntityInd',
#  'Return.ReturnData.IRS990.RelatedOrganizationCtrlEntInd',
#  'Return.ReturnData.IRS990.TrnsfrExmptNonChrtblRltdOrgInd',
#  'Return.ReturnData.IRS990.ActivitiesConductedPrtshpInd',
#  'Return.ReturnData.IRS990.ScheduleORequiredInd',
#  'Return.ReturnData.IRS990.IRPDocumentCnt',
#  'Return.ReturnData.IRS990.IRPDocumentW2GCnt',
#  'Return.ReturnData.IRS990.BackupWthldComplianceInd',
#  'Return.ReturnData.IRS990.EmployeeCnt',
#  'Return.ReturnData.IRS990.UnrelatedBusIncmOverLimitInd',
#  'Return.ReturnData.IRS990.ForeignFinancialAccountInd',
#  'Return.ReturnData.IRS990.ProhibitedTaxShelterTransInd',
#  'Return.ReturnData.IRS990.TaxablePartyNotificationInd',
#  'Return.ReturnData.IRS990.NondeductibleContributionsInd',
#  'Return.ReturnData.IRS990.QuidProQuoContributionsInd',
#  'Return.ReturnData.IRS990.Form8282PropertyDisposedOfInd',
#  'Return.ReturnData.IRS990.RcvFndsToPayPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.PayPremiumsPrsnlBnftCntrctInd',
#  'Return.ReturnData.IRS990.IndoorTanningServicesInd',
#  'Return.ReturnData.IRS990.InfoInScheduleOPartVIInd',
#  'Return.ReturnData.IRS990.GoverningBodyVotingMembersCnt',
#  'Return.ReturnData.IRS990.IndependentVotingMemberCnt',
#  'Return.ReturnData.IRS990.FamilyOrBusinessRlnInd',
#  'Return.ReturnData.IRS990.DelegationOfMgmtDutiesInd',
#  'Return.ReturnData.IRS990.ChangeToOrgDocumentsInd',
#  'Return.ReturnData.IRS990.MaterialDiversionOrMisuseInd',
#  'Return.ReturnData.IRS990.MembersOrStockholdersInd',
#  'Return.ReturnData.IRS990.ElectionOfBoardMembersInd',
#  'Return.ReturnData.IRS990.DecisionsSubjectToApprovaInd',
#  'Return.ReturnData.IRS990.MinutesOfGoverningBodyInd',
#  'Return.ReturnData.IRS990.MinutesOfCommitteesInd',
#  'Return.ReturnData.IRS990.OfficerMailingAddressInd',
#  'Return.ReturnData.IRS990.LocalChaptersInd',
#  'Return.ReturnData.IRS990.Form990ProvidedToGvrnBodyInd',
#  'Return.ReturnData.IRS990.ConflictOfInterestPolicyInd',
#  'Return.ReturnData.IRS990.AnnualDisclosureCoveredPrsnInd',
#  'Return.ReturnData.IRS990.RegularMonitoringEnfrcInd',
#  'Return.ReturnData.IRS990.WhistleblowerPolicyInd',
#  'Return.ReturnData.IRS990.DocumentRetentionPolicyInd',
#  'Return.ReturnData.IRS990.CompensationProcessCEOInd',
#  'Return.ReturnData.IRS990.CompensationProcessOtherInd',
#  'Return.ReturnData.IRS990.InvestmentInJointVentureInd',
#  'Return.ReturnData.IRS990.StatesWhereCopyOfReturnIsFldCd',
#  'Return.ReturnData.IRS990.OtherWebsiteInd',
#  'Return.ReturnData.IRS990.UponRequestInd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.PhoneNum',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.CityNm',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.BooksInCareOfDetail.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.PersonNm',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.TitleTxt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.AverageHoursPerWeekRt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.IndividualTrusteeOrDirectorInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OfficerInd',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.ReportableCompFromRltdOrgAmt',
#  'Return.ReturnData.IRS990.Form990PartVIISectionAGrp.OtherCompensationAmt',
#  'Return.ReturnData.IRS990.TotalReportableCompFromOrgAmt',
#  'Return.ReturnData.IRS990.TotReportableCompRltdOrgAmt',
#  'Return.ReturnData.IRS990.TotalOtherCompensationAmt',
#  'Return.ReturnData.IRS990.IndivRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.FormerOfcrEmployeesListedInd',
#  'Return.ReturnData.IRS990.TotalCompGreaterThan150KInd',
#  'Return.ReturnData.IRS990.CompensationFromOtherSrcsInd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorName.BusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.CityNm',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ContractorAddress.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.ServicesDesc',
#  'Return.ReturnData.IRS990.ContractorCompensationGrp.CompensationAmt',
#  'Return.ReturnData.IRS990.CntrctRcvdGreaterThan100KCnt',
#  'Return.ReturnData.IRS990.AllOtherContributionsAmt',
#  'Return.ReturnData.IRS990.NoncashContributionsAmt',
#  'Return.ReturnData.IRS990.TotalContributionsAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.Desc',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.BusinessCd',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.ProgramServiceRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalProgramServiceRevenueAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.InvestmentIncomeGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.LessCostOthBasisSalesExpnssGrp.OtherAmt',
#  'Return.ReturnData.IRS990.GainOrLossGrp.OtherAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.NetGainOrLossInvestmentsGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.Desc',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.BusinessCd',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.OtherRevenueMiscGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.OtherRevenueTotalAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.TotalRevenueColumnAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.UnrelatedBusinessRevenueAmt',
#  'Return.ReturnData.IRS990.TotalRevenueGrp.ExclusionAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.GrantsToDomesticOrgsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.CompCurrentOfcrDirectorsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherSalariesAndWagesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OtherEmployeeBenefitsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.PayrollTaxesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.TotalAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.FeesForServicesOtherGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AdvertisingGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OfficeExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InformationTechnologyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.OccupancyGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.TravelGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TravelGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TravelGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.TotalAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.ConferencesMeetingsGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InterestGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InterestGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InterestGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.TotalAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.DepreciationDepletionGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.TotalAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.InsuranceGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.Desc',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.OtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.AllOtherExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.TotalAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ProgramServicesAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.ManagementAndGeneralAmt',
#  'Return.ReturnData.IRS990.TotalFunctionalExpensesGrp.FundraisingAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.BOYAmt',
#  'Return.ReturnData.IRS990.CashNonInterestBearingGrp.EOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.BOYAmt',
#  'Return.ReturnData.IRS990.SavingsAndTempCashInvstGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OthNotesLoansReceivableNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InventoriesForSaleOrUseGrp.EOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.PrepaidExpensesDefrdChargesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipCostOrOtherBssAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipAccumDeprecAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.BOYAmt',
#  'Return.ReturnData.IRS990.LandBldgEquipBasisNetGrp.EOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.BOYAmt',
#  'Return.ReturnData.IRS990.InvestmentsPubTradedSecGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherAssetsTotalGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.BOYAmt',
#  'Return.ReturnData.IRS990.AccountsPayableAccrExpnssGrp.EOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.BOYAmt',
#  'Return.ReturnData.IRS990.MortgNotesPyblScrdInvstPropGrp.EOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnsecuredNotesLoansPayableGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.OtherLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalLiabilitiesGrp.EOYAmt',
#  'Return.ReturnData.IRS990.OrganizationFollowsSFAS117Ind',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.BOYAmt',
#  'Return.ReturnData.IRS990.UnrestrictedNetAssetsGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotalNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.BOYAmt',
#  'Return.ReturnData.IRS990.TotLiabNetAssetsFundBalanceGrp.EOYAmt',
#  'Return.ReturnData.IRS990.ReconcilationRevenueExpnssAmt',
#  'Return.ReturnData.IRS990.NetUnrlzdGainsLossesInvstAmt',
#  'Return.ReturnData.IRS990.OtherChangesInNetAssetsAmt',
#  'Return.ReturnData.IRS990.MethodOfAccountingAccrualInd',
#  'Return.ReturnData.IRS990.AccountantCompileOrReviewInd',
#  'Return.ReturnData.IRS990.FSAuditedInd',
#  'Return.ReturnData.IRS990.FSAuditedBasisGrp.SeparateBasisFinclStmtInd',
#  'Return.ReturnData.IRS990.AuditCommitteeInd',
#  'Return.ReturnData.IRS990.FederalGrantAuditRequiredInd',
#  'Return.ReturnData.IRS990ScheduleA.@documentId',
#  'Return.ReturnData.IRS990ScheduleA.PublicOrganization170Ind',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GiftsGrantsContriRcvd170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalCalendarYear170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.SubstantialContributorsTotAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportTotal170Amt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossInvestmentIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.CurrentTaxYearAmt',
#  'Return.ReturnData.IRS990ScheduleA.OtherIncome170Grp.TotalAmt',
#  'Return.ReturnData.IRS990ScheduleA.TotalSupportAmt',
#  'Return.ReturnData.IRS990ScheduleA.GrossReceiptsRltdActivitiesAmt',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportCY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.PublicSupportPY170Pct',
#  'Return.ReturnData.IRS990ScheduleA.ThirtyThrPctSuprtTestsCY170Ind',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleA.Form990ScheduleAPartVIGrp.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleB.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.@documentId',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.LeaseholdImprovementsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.EquipmentGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.OtherCostOrOtherBasisAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.DepreciationAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLandBuildingsGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueLandBuildingsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherAssetsOrgGrp.BookValueAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalBookValueOtherAssetsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Desc',
#  'Return.ReturnData.IRS990ScheduleD.OtherLiabilitiesOrgGrp.Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotalLiabilityAmt',
#  'Return.ReturnData.IRS990ScheduleD.FootnoteTextInd',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.NetUnrealizedGainsInvstAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesAndUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherRevenueAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.RevenueNotReportedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalRevenuePerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.TotExpnsEtcAuditedFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.DonatedServicesUseFcltsAmt',
#  'Return.ReturnData.IRS990ScheduleD.OtherExpensesIncludedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotReportedAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesSubtotalAmt',
#  'Return.ReturnData.IRS990ScheduleD.ExpensesNotRptFinclStmtAmt',
#  'Return.ReturnData.IRS990ScheduleD.TotalExpensesPerForm990Amt',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleD.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleI.@documentId',
#  'Return.ReturnData.IRS990ScheduleI.GrantRecordsMaintainedInd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientBusinessName.BusinessNameLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.AddressLine1Txt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.CityNm',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.StateAbbreviationCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.USAddress.ZIPCd',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.RecipientEIN',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.IRCSectionDesc',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.CashGrantAmt',
#  'Return.ReturnData.IRS990ScheduleI.RecipientTable.PurposeOfGrantTxt',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleI.SupplementalInformationDetail.ExplanationTxt',
#  'Return.ReturnData.IRS990ScheduleM.@documentId',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NonCashCheckboxInd',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.ContributionCnt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.NoncashContributionsRptF990Amt',
#  'Return.ReturnData.IRS990ScheduleM.RealEstateOtherGrp.MethodOfDeterminingRevenuesTxt',
#  'Return.ReturnData.IRS990ScheduleM.AnyPropertyThatMustBeHeldInd',
#  'Return.ReturnData.IRS990ScheduleM.ReviewProcessUnusualNCGiftsInd',
#  'Return.ReturnData.IRS990ScheduleM.ThirdPartiesUsedInd',
#  'Return.ReturnData.IRS990ScheduleO.@documentId',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'Return.ReturnData.IRS990ScheduleO.SupplementalInformationDetail.ExplanationTxt']

# %% [markdown]
# # start by cutting off the excess text

# %%
trimmed_list = []
for key in key_list:
    if key.startswith('Return.ReturnHeader.'):
        altered_key = key.rsplit('Return.ReturnHeader.')[-1]
        trimmed_list.append(altered_key)    
    elif key.startswith('Return.ReturnData.IRS990.'):
        altered_key = key.rsplit('Return.ReturnData.IRS990.')[-1]
        trimmed_list.append(altered_key)
    elif key.startswith('Return.ReturnData.IRS990'):
        altered_key = key.rsplit('Return.ReturnData.IRS990')[-1]
        trimmed_list.append(altered_key)
        
    else:
        trimmed_list.append(key)

# %%
trimmed_list
# Out:
# ['Return.@xmlns',
#  'Return.@xmlns:xsi',
#  'Return.@xsi:schemaLocation',
#  'Return.@returnVersion',
#  '@binaryAttachmentCnt',
#  'ReturnTs',
#  'TaxPeriodEndDt',
#  'PreparerFirmGrp.PreparerFirmEIN',
#  'PreparerFirmGrp.PreparerFirmName.BusinessNameLine1Txt',
#  'PreparerFirmGrp.PreparerUSAddress.AddressLine1Txt',
#  'PreparerFirmGrp.PreparerUSAddress.CityNm',
#  'PreparerFirmGrp.PreparerUSAddress.StateAbbreviationCd',
#  'PreparerFirmGrp.PreparerUSAddress.ZIPCd',
#  'ReturnTypeCd',
#  'TaxPeriodBeginDt',
#  'Filer.EIN',
#  'Filer.BusinessName.BusinessNameLine1Txt',
#  'Filer.BusinessNameControlTxt',
#  'Filer.PhoneNum',
#  'Filer.USAddress.AddressLine1Txt',
#  'Filer.USAddress.CityNm',
#  'Filer.USAddress.StateAbbreviationCd',
#  'Filer.USAddress.ZIPCd',
#  'BusinessOfficerGrp.PersonNm',
#  'BusinessOfficerGrp.PersonTitleTxt',
#  'BusinessOfficerGrp.PhoneNum',
#  'BusinessOfficerGrp.SignatureDt',
#  'BusinessOfficerGrp.DiscussWithPaidPreparerInd',
#  'PreparerPersonGrp.PreparerPersonNm',
#  'PreparerPersonGrp.PTIN',
#  'PreparerPersonGrp.PhoneNum',
#  'FilingSecurityInformation.IPAddress.IPv4AddressTxt',
#  'FilingSecurityInformation.IPDt',
#  'FilingSecurityInformation.IPTm',
#  'FilingSecurityInformation.IPTimezoneCd',
#  'FilingSecurityInformation.FilingLicenseTypeCd',
#  'FilingSecurityInformation.AtSubmissionCreationDeviceId',
#  'FilingSecurityInformation.AtSubmissionFilingDeviceId',
#  'TaxYr',
#  'BuildTS',
#  'Return.ReturnData.@documentCnt',
#  '@documentId',
#  '@referenceDocumentId',
#  'PrincipalOfficerNm',
#  'USAddress.AddressLine1Txt',
#  'USAddress.CityNm',
#  'USAddress.StateAbbreviationCd',
#  'USAddress.ZIPCd',
#  'GrossReceiptsAmt',
#  'GroupReturnForAffiliatesInd',
#  'Organization501c3Ind',
#  'WebsiteAddressTxt',
#  'TypeOfOrganizationCorpInd',
#  'FormationYr',
#  'LegalDomicileStateCd',
#  'ActivityOrMissionDesc',
#  'VotingMembersGoverningBodyCnt',
#  'VotingMembersIndependentCnt',
#  'TotalEmployeeCnt',
#  'TotalVolunteersCnt',
#  'TotalGrossUBIAmt',
#  'NetUnrelatedBusTxblIncmAmt',
#  'PYContributionsGrantsAmt',
#  'CYContributionsGrantsAmt',
#  'PYProgramServiceRevenueAmt',
#  'CYProgramServiceRevenueAmt',
#  'PYInvestmentIncomeAmt',
#  'CYInvestmentIncomeAmt',
#  'PYOtherRevenueAmt',
#  'CYOtherRevenueAmt',
#  'PYTotalRevenueAmt',
#  'CYTotalRevenueAmt',
#  'PYGrantsAndSimilarPaidAmt',
#  'CYGrantsAndSimilarPaidAmt',
#  'PYBenefitsPaidToMembersAmt',
#  'CYBenefitsPaidToMembersAmt',
#  'PYSalariesCompEmpBnftPaidAmt',
#  'CYSalariesCompEmpBnftPaidAmt',
#  'PYTotalProfFndrsngExpnsAmt',
#  'CYTotalProfFndrsngExpnsAmt',
#  'CYTotalFundraisingExpenseAmt',
#  'PYOtherExpensesAmt',
#  'CYOtherExpensesAmt',
#  'PYTotalExpensesAmt',
#  'CYTotalExpensesAmt',
#  'PYRevenuesLessExpensesAmt',
#  'CYRevenuesLessExpensesAmt',
#  'TotalAssetsBOYAmt',
#  'TotalAssetsEOYAmt',
#  'TotalLiabilitiesBOYAmt',
#  'TotalLiabilitiesEOYAmt',
#  'NetAssetsOrFundBalancesBOYAmt',
#  'NetAssetsOrFundBalancesEOYAmt',
#  'InfoInScheduleOPartIIIInd',
#  'MissionDesc',
#  'SignificantNewProgramSrvcInd',
#  'SignificantChangeInd',
#  'ExpenseAmt',
#  'GrantAmt',
#  'RevenueAmt',
#  'Desc',
#  'ProgSrvcAccomActy2Grp.ExpenseAmt',
#  'ProgSrvcAccomActy2Grp.RevenueAmt',
#  'ProgSrvcAccomActy2Grp.Desc',
#  'TotalProgramServiceExpensesAmt',
#  'DescribedInSection501c3Ind.@referenceDocumentId',
#  'DescribedInSection501c3Ind.#text',
#  'ScheduleBRequiredInd.@referenceDocumentId',
#  'ScheduleBRequiredInd.#text',
#  'PoliticalCampaignActyInd',
#  'LobbyingActivitiesInd',
#  'SubjectToProxyTaxInd',
#  'DonorAdvisedFundInd.@referenceDocumentId',
#  'DonorAdvisedFundInd.#text',
#  'ConservationEasementsInd.@referenceDocumentId',
#  'ConservationEasementsInd.#text',
#  'CollectionsOfArtInd.@referenceDocumentId',
#  'CollectionsOfArtInd.#text',
#  'CreditCounselingInd.@referenceDocumentId',
#  'CreditCounselingInd.#text',
#  'TempOrPermanentEndowmentsInd.@referenceDocumentId',
#  'TempOrPermanentEndowmentsInd.#text',
#  'ReportLandBuildingEquipmentInd.@referenceDocumentId',
#  'ReportLandBuildingEquipmentInd.#text',
#  'ReportInvestmentsOtherSecInd.@referenceDocumentId',
#  'ReportInvestmentsOtherSecInd.#text',
#  'ReportProgramRelatedInvstInd.@referenceDocumentId',
#  'ReportProgramRelatedInvstInd.#text',
#  'ReportOtherAssetsInd.@referenceDocumentId',
#  'ReportOtherAssetsInd.#text',
#  'ReportOtherLiabilitiesInd.@referenceDocumentId',
#  'ReportOtherLiabilitiesInd.#text',
#  'IncludeFIN48FootnoteInd.@referenceDocumentId',
#  'IncludeFIN48FootnoteInd.#text',
#  'IndependentAuditFinclStmtInd.@referenceDocumentId',
#  'IndependentAuditFinclStmtInd.#text',
#  'ConsolidatedAuditFinclStmtInd.@referenceDocumentId',
#  'ConsolidatedAuditFinclStmtInd.#text',
#  'SchoolOperatingInd',
#  'ForeignOfficeInd',
#  'ForeignActivitiesInd',
#  'MoreThan5000KToOrgInd',
#  'MoreThan5000KToIndividualsInd',
#  'ProfessionalFundraisingInd',
#  'FundraisingActivitiesInd',
#  'GamingActivitiesInd',
#  'OperateHospitalInd',
#  'GrantsToOrganizationsInd.@referenceDocumentId',
#  'GrantsToOrganizationsInd.#text',
#  'GrantsToIndividualsInd.@referenceDocumentId',
#  'GrantsToIndividualsInd.#text',
#  'ScheduleJRequiredInd',
#  'TaxExemptBondsInd',
#  'EngagedInExcessBenefitTransInd',
#  'PYExcessBenefitTransInd',
#  'LoanOutstandingInd',
#  'GrantToRelatedPersonInd',
#  'BusinessRlnWithOrgMemInd',
#  'BusinessRlnWithFamMemInd',
#  'BusinessRlnWithOfficerEntInd',
#  'DeductibleNonCashContriInd.@referenceDocumentId',
#  'DeductibleNonCashContriInd.#text',
#  'DeductibleArtContributionInd.@referenceDocumentId',
#  'DeductibleArtContributionInd.#text',
#  'TerminateOperationsInd',
#  'PartialLiquidationInd',
#  'DisregardedEntityInd',
#  'RelatedEntityInd',
#  'RelatedOrganizationCtrlEntInd',
#  'TrnsfrExmptNonChrtblRltdOrgInd',
#  'ActivitiesConductedPrtshpInd',
#  'ScheduleORequiredInd',
#  'IRPDocumentCnt',
#  'IRPDocumentW2GCnt',
#  'BackupWthldComplianceInd',
#  'EmployeeCnt',
#  'UnrelatedBusIncmOverLimitInd',
#  'ForeignFinancialAccountInd',
#  'ProhibitedTaxShelterTransInd',
#  'TaxablePartyNotificationInd',
#  'NondeductibleContributionsInd',
#  'QuidProQuoContributionsInd',
#  'Form8282PropertyDisposedOfInd',
#  'RcvFndsToPayPrsnlBnftCntrctInd',
#  'PayPremiumsPrsnlBnftCntrctInd',
#  'IndoorTanningServicesInd',
#  'InfoInScheduleOPartVIInd',
#  'GoverningBodyVotingMembersCnt',
#  'IndependentVotingMemberCnt',
#  'FamilyOrBusinessRlnInd',
#  'DelegationOfMgmtDutiesInd',
#  'ChangeToOrgDocumentsInd',
#  'MaterialDiversionOrMisuseInd',
#  'MembersOrStockholdersInd',
#  'ElectionOfBoardMembersInd',
#  'DecisionsSubjectToApprovaInd',
#  'MinutesOfGoverningBodyInd',
#  'MinutesOfCommitteesInd',
#  'OfficerMailingAddressInd',
#  'LocalChaptersInd',
#  'Form990ProvidedToGvrnBodyInd',
#  'ConflictOfInterestPolicyInd',
#  'AnnualDisclosureCoveredPrsnInd',
#  'RegularMonitoringEnfrcInd',
#  'WhistleblowerPolicyInd',
#  'DocumentRetentionPolicyInd',
#  'CompensationProcessCEOInd',
#  'CompensationProcessOtherInd',
#  'InvestmentInJointVentureInd',
#  'StatesWhereCopyOfReturnIsFldCd',
#  'OtherWebsiteInd',
#  'UponRequestInd',
#  'BooksInCareOfDetail.BusinessName.BusinessNameLine1Txt',
#  'BooksInCareOfDetail.PhoneNum',
#  'BooksInCareOfDetail.USAddress.AddressLine1Txt',
#  'BooksInCareOfDetail.USAddress.CityNm',
#  'BooksInCareOfDetail.USAddress.StateAbbreviationCd',
#  'BooksInCareOfDetail.USAddress.ZIPCd',
#  'Form990PartVIISectionAGrp.PersonNm',
#  'Form990PartVIISectionAGrp.TitleTxt',
#  'Form990PartVIISectionAGrp.AverageHoursPerWeekRt',
#  'Form990PartVIISectionAGrp.IndividualTrusteeOrDirectorInd',
#  'Form990PartVIISectionAGrp.OfficerInd',
#  'Form990PartVIISectionAGrp.ReportableCompFromOrgAmt',
#  'Form990PartVIISectionAGrp.ReportableCompFromRltdOrgAmt',
#  'Form990PartVIISectionAGrp.OtherCompensationAmt',
#  'TotalReportableCompFromOrgAmt',
#  'TotReportableCompRltdOrgAmt',
#  'TotalOtherCompensationAmt',
#  'IndivRcvdGreaterThan100KCnt',
#  'FormerOfcrEmployeesListedInd',
#  'TotalCompGreaterThan150KInd',
#  'CompensationFromOtherSrcsInd',
#  'ContractorCompensationGrp.ContractorName.BusinessName.BusinessNameLine1Txt',
#  'ContractorCompensationGrp.ContractorAddress.USAddress.AddressLine1Txt',
#  'ContractorCompensationGrp.ContractorAddress.USAddress.CityNm',
#  'ContractorCompensationGrp.ContractorAddress.USAddress.StateAbbreviationCd',
#  'ContractorCompensationGrp.ContractorAddress.USAddress.ZIPCd',
#  'ContractorCompensationGrp.ServicesDesc',
#  'ContractorCompensationGrp.CompensationAmt',
#  'CntrctRcvdGreaterThan100KCnt',
#  'AllOtherContributionsAmt',
#  'NoncashContributionsAmt',
#  'TotalContributionsAmt',
#  'ProgramServiceRevenueGrp.Desc',
#  'ProgramServiceRevenueGrp.BusinessCd',
#  'ProgramServiceRevenueGrp.TotalRevenueColumnAmt',
#  'ProgramServiceRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'TotalProgramServiceRevenueAmt',
#  'InvestmentIncomeGrp.TotalRevenueColumnAmt',
#  'InvestmentIncomeGrp.ExclusionAmt',
#  'LessCostOthBasisSalesExpnssGrp.OtherAmt',
#  'GainOrLossGrp.OtherAmt',
#  'NetGainOrLossInvestmentsGrp.TotalRevenueColumnAmt',
#  'NetGainOrLossInvestmentsGrp.ExclusionAmt',
#  'OtherRevenueMiscGrp.Desc',
#  'OtherRevenueMiscGrp.BusinessCd',
#  'OtherRevenueMiscGrp.TotalRevenueColumnAmt',
#  'OtherRevenueMiscGrp.ExclusionAmt',
#  'OtherRevenueTotalAmt',
#  'TotalRevenueGrp.TotalRevenueColumnAmt',
#  'TotalRevenueGrp.RelatedOrExemptFuncIncomeAmt',
#  'TotalRevenueGrp.UnrelatedBusinessRevenueAmt',
#  'TotalRevenueGrp.ExclusionAmt',
#  'GrantsToDomesticOrgsGrp.TotalAmt',
#  'GrantsToDomesticOrgsGrp.ProgramServicesAmt',
#  'CompCurrentOfcrDirectorsGrp.TotalAmt',
#  'CompCurrentOfcrDirectorsGrp.ProgramServicesAmt',
#  'CompCurrentOfcrDirectorsGrp.ManagementAndGeneralAmt',
#  'CompCurrentOfcrDirectorsGrp.FundraisingAmt',
#  'OtherSalariesAndWagesGrp.TotalAmt',
#  'OtherSalariesAndWagesGrp.ProgramServicesAmt',
#  'OtherSalariesAndWagesGrp.ManagementAndGeneralAmt',
#  'OtherSalariesAndWagesGrp.FundraisingAmt',
#  'OtherEmployeeBenefitsGrp.TotalAmt',
#  'OtherEmployeeBenefitsGrp.ProgramServicesAmt',
#  'OtherEmployeeBenefitsGrp.ManagementAndGeneralAmt',
#  'OtherEmployeeBenefitsGrp.FundraisingAmt',
#  'PayrollTaxesGrp.TotalAmt',
#  'PayrollTaxesGrp.ProgramServicesAmt',
#  'PayrollTaxesGrp.ManagementAndGeneralAmt',
#  'PayrollTaxesGrp.FundraisingAmt',
#  'FeesForServicesOtherGrp.TotalAmt',
#  'FeesForServicesOtherGrp.ProgramServicesAmt',
#  'FeesForServicesOtherGrp.ManagementAndGeneralAmt',
#  'FeesForServicesOtherGrp.FundraisingAmt',
#  'AdvertisingGrp.TotalAmt',
#  'AdvertisingGrp.ProgramServicesAmt',
#  'OfficeExpensesGrp.TotalAmt',
#  'OfficeExpensesGrp.ProgramServicesAmt',
#  'OfficeExpensesGrp.ManagementAndGeneralAmt',
#  'OfficeExpensesGrp.FundraisingAmt',
#  'InformationTechnologyGrp.TotalAmt',
#  'InformationTechnologyGrp.ProgramServicesAmt',
#  'InformationTechnologyGrp.ManagementAndGeneralAmt',
#  'InformationTechnologyGrp.FundraisingAmt',
#  'OccupancyGrp.TotalAmt',
#  'OccupancyGrp.ProgramServicesAmt',
#  'OccupancyGrp.ManagementAndGeneralAmt',
#  'OccupancyGrp.FundraisingAmt',
#  'TravelGrp.TotalAmt',
#  'TravelGrp.ProgramServicesAmt',
#  'TravelGrp.ManagementAndGeneralAmt',
#  'TravelGrp.FundraisingAmt',
#  'ConferencesMeetingsGrp.TotalAmt',
#  'ConferencesMeetingsGrp.ProgramServicesAmt',
#  'ConferencesMeetingsGrp.ManagementAndGeneralAmt',
#  'ConferencesMeetingsGrp.FundraisingAmt',
#  'InterestGrp.TotalAmt',
#  'InterestGrp.ProgramServicesAmt',
#  'InterestGrp.ManagementAndGeneralAmt',
#  'InterestGrp.FundraisingAmt',
#  'DepreciationDepletionGrp.TotalAmt',
#  'DepreciationDepletionGrp.ProgramServicesAmt',
#  'DepreciationDepletionGrp.ManagementAndGeneralAmt',
#  'DepreciationDepletionGrp.FundraisingAmt',
#  'InsuranceGrp.TotalAmt',
#  'InsuranceGrp.ProgramServicesAmt',
#  'InsuranceGrp.ManagementAndGeneralAmt',
#  'InsuranceGrp.FundraisingAmt',
#  'OtherExpensesGrp.Desc',
#  'OtherExpensesGrp.TotalAmt',
#  'OtherExpensesGrp.ProgramServicesAmt',
#  'AllOtherExpensesGrp.TotalAmt',
#  'AllOtherExpensesGrp.ProgramServicesAmt',
#  'TotalFunctionalExpensesGrp.TotalAmt',
#  'TotalFunctionalExpensesGrp.ProgramServicesAmt',
#  'TotalFunctionalExpensesGrp.ManagementAndGeneralAmt',
#  'TotalFunctionalExpensesGrp.FundraisingAmt',
#  'CashNonInterestBearingGrp.BOYAmt',
#  'CashNonInterestBearingGrp.EOYAmt',
#  'SavingsAndTempCashInvstGrp.BOYAmt',
#  'SavingsAndTempCashInvstGrp.EOYAmt',
#  'OthNotesLoansReceivableNetGrp.BOYAmt',
#  'OthNotesLoansReceivableNetGrp.EOYAmt',
#  'InventoriesForSaleOrUseGrp.BOYAmt',
#  'InventoriesForSaleOrUseGrp.EOYAmt',
#  'PrepaidExpensesDefrdChargesGrp.BOYAmt',
#  'PrepaidExpensesDefrdChargesGrp.EOYAmt',
#  'LandBldgEquipCostOrOtherBssAmt',
#  'LandBldgEquipAccumDeprecAmt',
#  'LandBldgEquipBasisNetGrp.BOYAmt',
#  'LandBldgEquipBasisNetGrp.EOYAmt',
#  'InvestmentsPubTradedSecGrp.BOYAmt',
#  'InvestmentsPubTradedSecGrp.EOYAmt',
#  'OtherAssetsTotalGrp.BOYAmt',
#  'OtherAssetsTotalGrp.EOYAmt',
#  'TotalAssetsGrp.BOYAmt',
#  'TotalAssetsGrp.EOYAmt',
#  'AccountsPayableAccrExpnssGrp.BOYAmt',
#  'AccountsPayableAccrExpnssGrp.EOYAmt',
#  'MortgNotesPyblScrdInvstPropGrp.BOYAmt',
#  'MortgNotesPyblScrdInvstPropGrp.EOYAmt',
#  'UnsecuredNotesLoansPayableGrp.BOYAmt',
#  'UnsecuredNotesLoansPayableGrp.EOYAmt',
#  'OtherLiabilitiesGrp.BOYAmt',
#  'OtherLiabilitiesGrp.EOYAmt',
#  'TotalLiabilitiesGrp.BOYAmt',
#  'TotalLiabilitiesGrp.EOYAmt',
#  'OrganizationFollowsSFAS117Ind',
#  'UnrestrictedNetAssetsGrp.BOYAmt',
#  'UnrestrictedNetAssetsGrp.EOYAmt',
#  'TotalNetAssetsFundBalanceGrp.BOYAmt',
#  'TotalNetAssetsFundBalanceGrp.EOYAmt',
#  'TotLiabNetAssetsFundBalanceGrp.BOYAmt',
#  'TotLiabNetAssetsFundBalanceGrp.EOYAmt',
#  'ReconcilationRevenueExpnssAmt',
#  'NetUnrlzdGainsLossesInvstAmt',
#  'OtherChangesInNetAssetsAmt',
#  'MethodOfAccountingAccrualInd',
#  'AccountantCompileOrReviewInd',
#  'FSAuditedInd',
#  'FSAuditedBasisGrp.SeparateBasisFinclStmtInd',
#  'AuditCommitteeInd',
#  'FederalGrantAuditRequiredInd',
#  'ScheduleA.@documentId',
#  'ScheduleA.PublicOrganization170Ind',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearMinus1YearAmt',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.CurrentTaxYearAmt',
#  'ScheduleA.GiftsGrantsContriRcvd170Grp.TotalAmt',
#  'ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearMinus1YearAmt',
#  'ScheduleA.TotalCalendarYear170Grp.CurrentTaxYearAmt',
#  'ScheduleA.TotalCalendarYear170Grp.TotalAmt',
#  'ScheduleA.SubstantialContributorsTotAmt',
#  'ScheduleA.PublicSupportTotal170Amt',
#  'ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'ScheduleA.GrossInvestmentIncome170Grp.CurrentTaxYearAmt',
#  'ScheduleA.GrossInvestmentIncome170Grp.TotalAmt',
#  'ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA.OtherIncome170Grp.CurrentTaxYearMinus1YearAmt',
#  'ScheduleA.OtherIncome170Grp.CurrentTaxYearAmt',
#  'ScheduleA.OtherIncome170Grp.TotalAmt',
#  'ScheduleA.TotalSupportAmt',
#  'ScheduleA.GrossReceiptsRltdActivitiesAmt',
#  'ScheduleA.PublicSupportCY170Pct',
#  'ScheduleA.PublicSupportPY170Pct',
#  'ScheduleA.ThirtyThrPctSuprtTestsCY170Ind',
#  'ScheduleA.Form990ScheduleAPartVIGrp.FormAndLineReferenceDesc',
#  'ScheduleA.Form990ScheduleAPartVIGrp.ExplanationTxt',
#  'ScheduleB.@documentId',
#  'ScheduleD.@documentId',
#  'ScheduleD.LeaseholdImprovementsGrp.OtherCostOrOtherBasisAmt',
#  'ScheduleD.LeaseholdImprovementsGrp.DepreciationAmt',
#  'ScheduleD.LeaseholdImprovementsGrp.BookValueAmt',
#  'ScheduleD.EquipmentGrp.OtherCostOrOtherBasisAmt',
#  'ScheduleD.EquipmentGrp.DepreciationAmt',
#  'ScheduleD.EquipmentGrp.BookValueAmt',
#  'ScheduleD.OtherLandBuildingsGrp.OtherCostOrOtherBasisAmt',
#  'ScheduleD.OtherLandBuildingsGrp.DepreciationAmt',
#  'ScheduleD.OtherLandBuildingsGrp.BookValueAmt',
#  'ScheduleD.TotalBookValueLandBuildingsAmt',
#  'ScheduleD.OtherAssetsOrgGrp.Desc',
#  'ScheduleD.OtherAssetsOrgGrp.BookValueAmt',
#  'ScheduleD.TotalBookValueOtherAssetsAmt',
#  'ScheduleD.OtherLiabilitiesOrgGrp.Desc',
#  'ScheduleD.OtherLiabilitiesOrgGrp.Amt',
#  'ScheduleD.TotalLiabilityAmt',
#  'ScheduleD.FootnoteTextInd',
#  'ScheduleD.TotalRevEtcAuditedFinclStmtAmt',
#  'ScheduleD.NetUnrealizedGainsInvstAmt',
#  'ScheduleD.DonatedServicesAndUseFcltsAmt',
#  'ScheduleD.OtherRevenueAmt',
#  'ScheduleD.RevenueNotReportedAmt',
#  'ScheduleD.RevenueSubtotalAmt',
#  'ScheduleD.RevenueNotReportedFinclStmtAmt',
#  'ScheduleD.TotalRevenuePerForm990Amt',
#  'ScheduleD.TotExpnsEtcAuditedFinclStmtAmt',
#  'ScheduleD.DonatedServicesUseFcltsAmt',
#  'ScheduleD.OtherExpensesIncludedAmt',
#  'ScheduleD.ExpensesNotReportedAmt',
#  'ScheduleD.ExpensesSubtotalAmt',
#  'ScheduleD.ExpensesNotRptFinclStmtAmt',
#  'ScheduleD.TotalExpensesPerForm990Amt',
#  'ScheduleD.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'ScheduleD.SupplementalInformationDetail.ExplanationTxt',
#  'ScheduleI.@documentId',
#  'ScheduleI.GrantRecordsMaintainedInd',
#  'ScheduleI.RecipientTable.RecipientBusinessName.BusinessNameLine1Txt',
#  'ScheduleI.RecipientTable.USAddress.AddressLine1Txt',
#  'ScheduleI.RecipientTable.USAddress.CityNm',
#  'ScheduleI.RecipientTable.USAddress.StateAbbreviationCd',
#  'ScheduleI.RecipientTable.USAddress.ZIPCd',
#  'ScheduleI.RecipientTable.RecipientEIN',
#  'ScheduleI.RecipientTable.IRCSectionDesc',
#  'ScheduleI.RecipientTable.CashGrantAmt',
#  'ScheduleI.RecipientTable.PurposeOfGrantTxt',
#  'ScheduleI.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'ScheduleI.SupplementalInformationDetail.ExplanationTxt',
#  'ScheduleM.@documentId',
#  'ScheduleM.RealEstateOtherGrp.NonCashCheckboxInd',
#  'ScheduleM.RealEstateOtherGrp.ContributionCnt',
#  'ScheduleM.RealEstateOtherGrp.NoncashContributionsRptF990Amt',
#  'ScheduleM.RealEstateOtherGrp.MethodOfDeterminingRevenuesTxt',
#  'ScheduleM.AnyPropertyThatMustBeHeldInd',
#  'ScheduleM.ReviewProcessUnusualNCGiftsInd',
#  'ScheduleM.ThirdPartiesUsedInd',
#  'ScheduleO.@documentId',
#  'ScheduleO.SupplementalInformationDetail.FormAndLineReferenceDesc',
#  'ScheduleO.SupplementalInformationDetail.ExplanationTxt']

# %% [markdown]
# # swap special characters for their pronunciation

# %%
# swap # with 'hashtag'
no_hashtag_list = []
for key in trimmed_list:
    no_hashtag_list.append(key.replace('#', 'hashtag.'))
    
no_at_list = []
for key in no_hashtag_list:
    no_at_list.append(key.replace('@', 'at.'))

outlist = []
for key in no_at_list:
    outlist.append(key.replace('.', '_'))

# %%
outlist
# Out:
# ['Return_at_xmlns',
#  'Return_at_xmlns:xsi',
#  'Return_at_xsi:schemaLocation',
#  'Return_at_returnVersion',
#  'at_binaryAttachmentCnt',
#  'ReturnTs',
#  'TaxPeriodEndDt',
#  'PreparerFirmGrp_PreparerFirmEIN',
#  'PreparerFirmGrp_PreparerFirmName_BusinessNameLine1Txt',
#  'PreparerFirmGrp_PreparerUSAddress_AddressLine1Txt',
#  'PreparerFirmGrp_PreparerUSAddress_CityNm',
#  'PreparerFirmGrp_PreparerUSAddress_StateAbbreviationCd',
#  'PreparerFirmGrp_PreparerUSAddress_ZIPCd',
#  'ReturnTypeCd',
#  'TaxPeriodBeginDt',
#  'Filer_EIN',
#  'Filer_BusinessName_BusinessNameLine1Txt',
#  'Filer_BusinessNameControlTxt',
#  'Filer_PhoneNum',
#  'Filer_USAddress_AddressLine1Txt',
#  'Filer_USAddress_CityNm',
#  'Filer_USAddress_StateAbbreviationCd',
#  'Filer_USAddress_ZIPCd',
#  'BusinessOfficerGrp_PersonNm',
#  'BusinessOfficerGrp_PersonTitleTxt',
#  'BusinessOfficerGrp_PhoneNum',
#  'BusinessOfficerGrp_SignatureDt',
#  'BusinessOfficerGrp_DiscussWithPaidPreparerInd',
#  'PreparerPersonGrp_PreparerPersonNm',
#  'PreparerPersonGrp_PTIN',
#  'PreparerPersonGrp_PhoneNum',
#  'FilingSecurityInformation_IPAddress_IPv4AddressTxt',
#  'FilingSecurityInformation_IPDt',
#  'FilingSecurityInformation_IPTm',
#  'FilingSecurityInformation_IPTimezoneCd',
#  'FilingSecurityInformation_FilingLicenseTypeCd',
#  'FilingSecurityInformation_AtSubmissionCreationDeviceId',
#  'FilingSecurityInformation_AtSubmissionFilingDeviceId',
#  'TaxYr',
#  'BuildTS',
#  'Return_ReturnData_at_documentCnt',
#  'at_documentId',
#  'at_referenceDocumentId',
#  'PrincipalOfficerNm',
#  'USAddress_AddressLine1Txt',
#  'USAddress_CityNm',
#  'USAddress_StateAbbreviationCd',
#  'USAddress_ZIPCd',
#  'GrossReceiptsAmt',
#  'GroupReturnForAffiliatesInd',
#  'Organization501c3Ind',
#  'WebsiteAddressTxt',
#  'TypeOfOrganizationCorpInd',
#  'FormationYr',
#  'LegalDomicileStateCd',
#  'ActivityOrMissionDesc',
#  'VotingMembersGoverningBodyCnt',
#  'VotingMembersIndependentCnt',
#  'TotalEmployeeCnt',
#  'TotalVolunteersCnt',
#  'TotalGrossUBIAmt',
#  'NetUnrelatedBusTxblIncmAmt',
#  'PYContributionsGrantsAmt',
#  'CYContributionsGrantsAmt',
#  'PYProgramServiceRevenueAmt',
#  'CYProgramServiceRevenueAmt',
#  'PYInvestmentIncomeAmt',
#  'CYInvestmentIncomeAmt',
#  'PYOtherRevenueAmt',
#  'CYOtherRevenueAmt',
#  'PYTotalRevenueAmt',
#  'CYTotalRevenueAmt',
#  'PYGrantsAndSimilarPaidAmt',
#  'CYGrantsAndSimilarPaidAmt',
#  'PYBenefitsPaidToMembersAmt',
#  'CYBenefitsPaidToMembersAmt',
#  'PYSalariesCompEmpBnftPaidAmt',
#  'CYSalariesCompEmpBnftPaidAmt',
#  'PYTotalProfFndrsngExpnsAmt',
#  'CYTotalProfFndrsngExpnsAmt',
#  'CYTotalFundraisingExpenseAmt',
#  'PYOtherExpensesAmt',
#  'CYOtherExpensesAmt',
#  'PYTotalExpensesAmt',
#  'CYTotalExpensesAmt',
#  'PYRevenuesLessExpensesAmt',
#  'CYRevenuesLessExpensesAmt',
#  'TotalAssetsBOYAmt',
#  'TotalAssetsEOYAmt',
#  'TotalLiabilitiesBOYAmt',
#  'TotalLiabilitiesEOYAmt',
#  'NetAssetsOrFundBalancesBOYAmt',
#  'NetAssetsOrFundBalancesEOYAmt',
#  'InfoInScheduleOPartIIIInd',
#  'MissionDesc',
#  'SignificantNewProgramSrvcInd',
#  'SignificantChangeInd',
#  'ExpenseAmt',
#  'GrantAmt',
#  'RevenueAmt',
#  'Desc',
#  'ProgSrvcAccomActy2Grp_ExpenseAmt',
#  'ProgSrvcAccomActy2Grp_RevenueAmt',
#  'ProgSrvcAccomActy2Grp_Desc',
#  'TotalProgramServiceExpensesAmt',
#  'DescribedInSection501c3Ind_at_referenceDocumentId',
#  'DescribedInSection501c3Ind_hashtag_text',
#  'ScheduleBRequiredInd_at_referenceDocumentId',
#  'ScheduleBRequiredInd_hashtag_text',
#  'PoliticalCampaignActyInd',
#  'LobbyingActivitiesInd',
#  'SubjectToProxyTaxInd',
#  'DonorAdvisedFundInd_at_referenceDocumentId',
#  'DonorAdvisedFundInd_hashtag_text',
#  'ConservationEasementsInd_at_referenceDocumentId',
#  'ConservationEasementsInd_hashtag_text',
#  'CollectionsOfArtInd_at_referenceDocumentId',
#  'CollectionsOfArtInd_hashtag_text',
#  'CreditCounselingInd_at_referenceDocumentId',
#  'CreditCounselingInd_hashtag_text',
#  'TempOrPermanentEndowmentsInd_at_referenceDocumentId',
#  'TempOrPermanentEndowmentsInd_hashtag_text',
#  'ReportLandBuildingEquipmentInd_at_referenceDocumentId',
#  'ReportLandBuildingEquipmentInd_hashtag_text',
#  'ReportInvestmentsOtherSecInd_at_referenceDocumentId',
#  'ReportInvestmentsOtherSecInd_hashtag_text',
#  'ReportProgramRelatedInvstInd_at_referenceDocumentId',
#  'ReportProgramRelatedInvstInd_hashtag_text',
#  'ReportOtherAssetsInd_at_referenceDocumentId',
#  'ReportOtherAssetsInd_hashtag_text',
#  'ReportOtherLiabilitiesInd_at_referenceDocumentId',
#  'ReportOtherLiabilitiesInd_hashtag_text',
#  'IncludeFIN48FootnoteInd_at_referenceDocumentId',
#  'IncludeFIN48FootnoteInd_hashtag_text',
#  'IndependentAuditFinclStmtInd_at_referenceDocumentId',
#  'IndependentAuditFinclStmtInd_hashtag_text',
#  'ConsolidatedAuditFinclStmtInd_at_referenceDocumentId',
#  'ConsolidatedAuditFinclStmtInd_hashtag_text',
#  'SchoolOperatingInd',
#  'ForeignOfficeInd',
#  'ForeignActivitiesInd',
#  'MoreThan5000KToOrgInd',
#  'MoreThan5000KToIndividualsInd',
#  'ProfessionalFundraisingInd',
#  'FundraisingActivitiesInd',
#  'GamingActivitiesInd',
#  'OperateHospitalInd',
#  'GrantsToOrganizationsInd_at_referenceDocumentId',
#  'GrantsToOrganizationsInd_hashtag_text',
#  'GrantsToIndividualsInd_at_referenceDocumentId',
#  'GrantsToIndividualsInd_hashtag_text',
#  'ScheduleJRequiredInd',
#  'TaxExemptBondsInd',
#  'EngagedInExcessBenefitTransInd',
#  'PYExcessBenefitTransInd',
#  'LoanOutstandingInd',
#  'GrantToRelatedPersonInd',
#  'BusinessRlnWithOrgMemInd',
#  'BusinessRlnWithFamMemInd',
#  'BusinessRlnWithOfficerEntInd',
#  'DeductibleNonCashContriInd_at_referenceDocumentId',
#  'DeductibleNonCashContriInd_hashtag_text',
#  'DeductibleArtContributionInd_at_referenceDocumentId',
#  'DeductibleArtContributionInd_hashtag_text',
#  'TerminateOperationsInd',
#  'PartialLiquidationInd',
#  'DisregardedEntityInd',
#  'RelatedEntityInd',
#  'RelatedOrganizationCtrlEntInd',
#  'TrnsfrExmptNonChrtblRltdOrgInd',
#  'ActivitiesConductedPrtshpInd',
#  'ScheduleORequiredInd',
#  'IRPDocumentCnt',
#  'IRPDocumentW2GCnt',
#  'BackupWthldComplianceInd',
#  'EmployeeCnt',
#  'UnrelatedBusIncmOverLimitInd',
#  'ForeignFinancialAccountInd',
#  'ProhibitedTaxShelterTransInd',
#  'TaxablePartyNotificationInd',
#  'NondeductibleContributionsInd',
#  'QuidProQuoContributionsInd',
#  'Form8282PropertyDisposedOfInd',
#  'RcvFndsToPayPrsnlBnftCntrctInd',
#  'PayPremiumsPrsnlBnftCntrctInd',
#  'IndoorTanningServicesInd',
#  'InfoInScheduleOPartVIInd',
#  'GoverningBodyVotingMembersCnt',
#  'IndependentVotingMemberCnt',
#  'FamilyOrBusinessRlnInd',
#  'DelegationOfMgmtDutiesInd',
#  'ChangeToOrgDocumentsInd',
#  'MaterialDiversionOrMisuseInd',
#  'MembersOrStockholdersInd',
#  'ElectionOfBoardMembersInd',
#  'DecisionsSubjectToApprovaInd',
#  'MinutesOfGoverningBodyInd',
#  'MinutesOfCommitteesInd',
#  'OfficerMailingAddressInd',
#  'LocalChaptersInd',
#  'Form990ProvidedToGvrnBodyInd',
#  'ConflictOfInterestPolicyInd',
#  'AnnualDisclosureCoveredPrsnInd',
#  'RegularMonitoringEnfrcInd',
#  'WhistleblowerPolicyInd',
#  'DocumentRetentionPolicyInd',
#  'CompensationProcessCEOInd',
#  'CompensationProcessOtherInd',
#  'InvestmentInJointVentureInd',
#  'StatesWhereCopyOfReturnIsFldCd',
#  'OtherWebsiteInd',
#  'UponRequestInd',
#  'BooksInCareOfDetail_BusinessName_BusinessNameLine1Txt',
#  'BooksInCareOfDetail_PhoneNum',
#  'BooksInCareOfDetail_USAddress_AddressLine1Txt',
#  'BooksInCareOfDetail_USAddress_CityNm',
#  'BooksInCareOfDetail_USAddress_StateAbbreviationCd',
#  'BooksInCareOfDetail_USAddress_ZIPCd',
#  'Form990PartVIISectionAGrp_PersonNm',
#  'Form990PartVIISectionAGrp_TitleTxt',
#  'Form990PartVIISectionAGrp_AverageHoursPerWeekRt',
#  'Form990PartVIISectionAGrp_IndividualTrusteeOrDirectorInd',
#  'Form990PartVIISectionAGrp_OfficerInd',
#  'Form990PartVIISectionAGrp_ReportableCompFromOrgAmt',
#  'Form990PartVIISectionAGrp_ReportableCompFromRltdOrgAmt',
#  'Form990PartVIISectionAGrp_OtherCompensationAmt',
#  'TotalReportableCompFromOrgAmt',
#  'TotReportableCompRltdOrgAmt',
#  'TotalOtherCompensationAmt',
#  'IndivRcvdGreaterThan100KCnt',
#  'FormerOfcrEmployeesListedInd',
#  'TotalCompGreaterThan150KInd',
#  'CompensationFromOtherSrcsInd',
#  'ContractorCompensationGrp_ContractorName_BusinessName_BusinessNameLine1Txt',
#  'ContractorCompensationGrp_ContractorAddress_USAddress_AddressLine1Txt',
#  'ContractorCompensationGrp_ContractorAddress_USAddress_CityNm',
#  'ContractorCompensationGrp_ContractorAddress_USAddress_StateAbbreviationCd',
#  'ContractorCompensationGrp_ContractorAddress_USAddress_ZIPCd',
#  'ContractorCompensationGrp_ServicesDesc',
#  'ContractorCompensationGrp_CompensationAmt',
#  'CntrctRcvdGreaterThan100KCnt',
#  'AllOtherContributionsAmt',
#  'NoncashContributionsAmt',
#  'TotalContributionsAmt',
#  'ProgramServiceRevenueGrp_Desc',
#  'ProgramServiceRevenueGrp_BusinessCd',
#  'ProgramServiceRevenueGrp_TotalRevenueColumnAmt',
#  'ProgramServiceRevenueGrp_RelatedOrExemptFuncIncomeAmt',
#  'TotalProgramServiceRevenueAmt',
#  'InvestmentIncomeGrp_TotalRevenueColumnAmt',
#  'InvestmentIncomeGrp_ExclusionAmt',
#  'LessCostOthBasisSalesExpnssGrp_OtherAmt',
#  'GainOrLossGrp_OtherAmt',
#  'NetGainOrLossInvestmentsGrp_TotalRevenueColumnAmt',
#  'NetGainOrLossInvestmentsGrp_ExclusionAmt',
#  'OtherRevenueMiscGrp_Desc',
#  'OtherRevenueMiscGrp_BusinessCd',
#  'OtherRevenueMiscGrp_TotalRevenueColumnAmt',
#  'OtherRevenueMiscGrp_ExclusionAmt',
#  'OtherRevenueTotalAmt',
#  'TotalRevenueGrp_TotalRevenueColumnAmt',
#  'TotalRevenueGrp_RelatedOrExemptFuncIncomeAmt',
#  'TotalRevenueGrp_UnrelatedBusinessRevenueAmt',
#  'TotalRevenueGrp_ExclusionAmt',
#  'GrantsToDomesticOrgsGrp_TotalAmt',
#  'GrantsToDomesticOrgsGrp_ProgramServicesAmt',
#  'CompCurrentOfcrDirectorsGrp_TotalAmt',
#  'CompCurrentOfcrDirectorsGrp_ProgramServicesAmt',
#  'CompCurrentOfcrDirectorsGrp_ManagementAndGeneralAmt',
#  'CompCurrentOfcrDirectorsGrp_FundraisingAmt',
#  'OtherSalariesAndWagesGrp_TotalAmt',
#  'OtherSalariesAndWagesGrp_ProgramServicesAmt',
#  'OtherSalariesAndWagesGrp_ManagementAndGeneralAmt',
#  'OtherSalariesAndWagesGrp_FundraisingAmt',
#  'OtherEmployeeBenefitsGrp_TotalAmt',
#  'OtherEmployeeBenefitsGrp_ProgramServicesAmt',
#  'OtherEmployeeBenefitsGrp_ManagementAndGeneralAmt',
#  'OtherEmployeeBenefitsGrp_FundraisingAmt',
#  'PayrollTaxesGrp_TotalAmt',
#  'PayrollTaxesGrp_ProgramServicesAmt',
#  'PayrollTaxesGrp_ManagementAndGeneralAmt',
#  'PayrollTaxesGrp_FundraisingAmt',
#  'FeesForServicesOtherGrp_TotalAmt',
#  'FeesForServicesOtherGrp_ProgramServicesAmt',
#  'FeesForServicesOtherGrp_ManagementAndGeneralAmt',
#  'FeesForServicesOtherGrp_FundraisingAmt',
#  'AdvertisingGrp_TotalAmt',
#  'AdvertisingGrp_ProgramServicesAmt',
#  'OfficeExpensesGrp_TotalAmt',
#  'OfficeExpensesGrp_ProgramServicesAmt',
#  'OfficeExpensesGrp_ManagementAndGeneralAmt',
#  'OfficeExpensesGrp_FundraisingAmt',
#  'InformationTechnologyGrp_TotalAmt',
#  'InformationTechnologyGrp_ProgramServicesAmt',
#  'InformationTechnologyGrp_ManagementAndGeneralAmt',
#  'InformationTechnologyGrp_FundraisingAmt',
#  'OccupancyGrp_TotalAmt',
#  'OccupancyGrp_ProgramServicesAmt',
#  'OccupancyGrp_ManagementAndGeneralAmt',
#  'OccupancyGrp_FundraisingAmt',
#  'TravelGrp_TotalAmt',
#  'TravelGrp_ProgramServicesAmt',
#  'TravelGrp_ManagementAndGeneralAmt',
#  'TravelGrp_FundraisingAmt',
#  'ConferencesMeetingsGrp_TotalAmt',
#  'ConferencesMeetingsGrp_ProgramServicesAmt',
#  'ConferencesMeetingsGrp_ManagementAndGeneralAmt',
#  'ConferencesMeetingsGrp_FundraisingAmt',
#  'InterestGrp_TotalAmt',
#  'InterestGrp_ProgramServicesAmt',
#  'InterestGrp_ManagementAndGeneralAmt',
#  'InterestGrp_FundraisingAmt',
#  'DepreciationDepletionGrp_TotalAmt',
#  'DepreciationDepletionGrp_ProgramServicesAmt',
#  'DepreciationDepletionGrp_ManagementAndGeneralAmt',
#  'DepreciationDepletionGrp_FundraisingAmt',
#  'InsuranceGrp_TotalAmt',
#  'InsuranceGrp_ProgramServicesAmt',
#  'InsuranceGrp_ManagementAndGeneralAmt',
#  'InsuranceGrp_FundraisingAmt',
#  'OtherExpensesGrp_Desc',
#  'OtherExpensesGrp_TotalAmt',
#  'OtherExpensesGrp_ProgramServicesAmt',
#  'AllOtherExpensesGrp_TotalAmt',
#  'AllOtherExpensesGrp_ProgramServicesAmt',
#  'TotalFunctionalExpensesGrp_TotalAmt',
#  'TotalFunctionalExpensesGrp_ProgramServicesAmt',
#  'TotalFunctionalExpensesGrp_ManagementAndGeneralAmt',
#  'TotalFunctionalExpensesGrp_FundraisingAmt',
#  'CashNonInterestBearingGrp_BOYAmt',
#  'CashNonInterestBearingGrp_EOYAmt',
#  'SavingsAndTempCashInvstGrp_BOYAmt',
#  'SavingsAndTempCashInvstGrp_EOYAmt',
#  'OthNotesLoansReceivableNetGrp_BOYAmt',
#  'OthNotesLoansReceivableNetGrp_EOYAmt',
#  'InventoriesForSaleOrUseGrp_BOYAmt',
#  'InventoriesForSaleOrUseGrp_EOYAmt',
#  'PrepaidExpensesDefrdChargesGrp_BOYAmt',
#  'PrepaidExpensesDefrdChargesGrp_EOYAmt',
#  'LandBldgEquipCostOrOtherBssAmt',
#  'LandBldgEquipAccumDeprecAmt',
#  'LandBldgEquipBasisNetGrp_BOYAmt',
#  'LandBldgEquipBasisNetGrp_EOYAmt',
#  'InvestmentsPubTradedSecGrp_BOYAmt',
#  'InvestmentsPubTradedSecGrp_EOYAmt',
#  'OtherAssetsTotalGrp_BOYAmt',
#  'OtherAssetsTotalGrp_EOYAmt',
#  'TotalAssetsGrp_BOYAmt',
#  'TotalAssetsGrp_EOYAmt',
#  'AccountsPayableAccrExpnssGrp_BOYAmt',
#  'AccountsPayableAccrExpnssGrp_EOYAmt',
#  'MortgNotesPyblScrdInvstPropGrp_BOYAmt',
#  'MortgNotesPyblScrdInvstPropGrp_EOYAmt',
#  'UnsecuredNotesLoansPayableGrp_BOYAmt',
#  'UnsecuredNotesLoansPayableGrp_EOYAmt',
#  'OtherLiabilitiesGrp_BOYAmt',
#  'OtherLiabilitiesGrp_EOYAmt',
#  'TotalLiabilitiesGrp_BOYAmt',
#  'TotalLiabilitiesGrp_EOYAmt',
#  'OrganizationFollowsSFAS117Ind',
#  'UnrestrictedNetAssetsGrp_BOYAmt',
#  'UnrestrictedNetAssetsGrp_EOYAmt',
#  'TotalNetAssetsFundBalanceGrp_BOYAmt',
#  'TotalNetAssetsFundBalanceGrp_EOYAmt',
#  'TotLiabNetAssetsFundBalanceGrp_BOYAmt',
#  'TotLiabNetAssetsFundBalanceGrp_EOYAmt',
#  'ReconcilationRevenueExpnssAmt',
#  'NetUnrlzdGainsLossesInvstAmt',
#  'OtherChangesInNetAssetsAmt',
#  'MethodOfAccountingAccrualInd',
#  'AccountantCompileOrReviewInd',
#  'FSAuditedInd',
#  'FSAuditedBasisGrp_SeparateBasisFinclStmtInd',
#  'AuditCommitteeInd',
#  'FederalGrantAuditRequiredInd',
#  'ScheduleA_at_documentId',
#  'ScheduleA_PublicOrganization170Ind',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_CurrentTaxYearMinus1YearAmt',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_CurrentTaxYearAmt',
#  'ScheduleA_GiftsGrantsContriRcvd170Grp_TotalAmt',
#  'ScheduleA_TotalCalendarYear170Grp_CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA_TotalCalendarYear170Grp_CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA_TotalCalendarYear170Grp_CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA_TotalCalendarYear170Grp_CurrentTaxYearMinus1YearAmt',
#  'ScheduleA_TotalCalendarYear170Grp_CurrentTaxYearAmt',
#  'ScheduleA_TotalCalendarYear170Grp_TotalAmt',
#  'ScheduleA_SubstantialContributorsTotAmt',
#  'ScheduleA_PublicSupportTotal170Amt',
#  'ScheduleA_GrossInvestmentIncome170Grp_CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA_GrossInvestmentIncome170Grp_CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA_GrossInvestmentIncome170Grp_CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA_GrossInvestmentIncome170Grp_CurrentTaxYearMinus1YearAmt',
#  'ScheduleA_GrossInvestmentIncome170Grp_CurrentTaxYearAmt',
#  'ScheduleA_GrossInvestmentIncome170Grp_TotalAmt',
#  'ScheduleA_OtherIncome170Grp_CurrentTaxYearMinus4YearsAmt',
#  'ScheduleA_OtherIncome170Grp_CurrentTaxYearMinus3YearsAmt',
#  'ScheduleA_OtherIncome170Grp_CurrentTaxYearMinus2YearsAmt',
#  'ScheduleA_OtherIncome170Grp_CurrentTaxYearMinus1YearAmt',
#  'ScheduleA_OtherIncome170Grp_CurrentTaxYearAmt',
#  'ScheduleA_OtherIncome170Grp_TotalAmt',
#  'ScheduleA_TotalSupportAmt',
#  'ScheduleA_GrossReceiptsRltdActivitiesAmt',
#  'ScheduleA_PublicSupportCY170Pct',
#  'ScheduleA_PublicSupportPY170Pct',
#  'ScheduleA_ThirtyThrPctSuprtTestsCY170Ind',
#  'ScheduleA_Form990ScheduleAPartVIGrp_FormAndLineReferenceDesc',
#  'ScheduleA_Form990ScheduleAPartVIGrp_ExplanationTxt',
#  'ScheduleB_at_documentId',
#  'ScheduleD_at_documentId',
#  'ScheduleD_LeaseholdImprovementsGrp_OtherCostOrOtherBasisAmt',
#  'ScheduleD_LeaseholdImprovementsGrp_DepreciationAmt',
#  'ScheduleD_LeaseholdImprovementsGrp_BookValueAmt',
#  'ScheduleD_EquipmentGrp_OtherCostOrOtherBasisAmt',
#  'ScheduleD_EquipmentGrp_DepreciationAmt',
#  'ScheduleD_EquipmentGrp_BookValueAmt',
#  'ScheduleD_OtherLandBuildingsGrp_OtherCostOrOtherBasisAmt',
#  'ScheduleD_OtherLandBuildingsGrp_DepreciationAmt',
#  'ScheduleD_OtherLandBuildingsGrp_BookValueAmt',
#  'ScheduleD_TotalBookValueLandBuildingsAmt',
#  'ScheduleD_OtherAssetsOrgGrp_Desc',
#  'ScheduleD_OtherAssetsOrgGrp_BookValueAmt',
#  'ScheduleD_TotalBookValueOtherAssetsAmt',
#  'ScheduleD_OtherLiabilitiesOrgGrp_Desc',
#  'ScheduleD_OtherLiabilitiesOrgGrp_Amt',
#  'ScheduleD_TotalLiabilityAmt',
#  'ScheduleD_FootnoteTextInd',
#  'ScheduleD_TotalRevEtcAuditedFinclStmtAmt',
#  'ScheduleD_NetUnrealizedGainsInvstAmt',
#  'ScheduleD_DonatedServicesAndUseFcltsAmt',
#  'ScheduleD_OtherRevenueAmt',
#  'ScheduleD_RevenueNotReportedAmt',
#  'ScheduleD_RevenueSubtotalAmt',
#  'ScheduleD_RevenueNotReportedFinclStmtAmt',
#  'ScheduleD_TotalRevenuePerForm990Amt',
#  'ScheduleD_TotExpnsEtcAuditedFinclStmtAmt',
#  'ScheduleD_DonatedServicesUseFcltsAmt',
#  'ScheduleD_OtherExpensesIncludedAmt',
#  'ScheduleD_ExpensesNotReportedAmt',
#  'ScheduleD_ExpensesSubtotalAmt',
#  'ScheduleD_ExpensesNotRptFinclStmtAmt',
#  'ScheduleD_TotalExpensesPerForm990Amt',
#  'ScheduleD_SupplementalInformationDetail_FormAndLineReferenceDesc',
#  'ScheduleD_SupplementalInformationDetail_ExplanationTxt',
#  'ScheduleI_at_documentId',
#  'ScheduleI_GrantRecordsMaintainedInd',
#  'ScheduleI_RecipientTable_RecipientBusinessName_BusinessNameLine1Txt',
#  'ScheduleI_RecipientTable_USAddress_AddressLine1Txt',
#  'ScheduleI_RecipientTable_USAddress_CityNm',
#  'ScheduleI_RecipientTable_USAddress_StateAbbreviationCd',
#  'ScheduleI_RecipientTable_USAddress_ZIPCd',
#  'ScheduleI_RecipientTable_RecipientEIN',
#  'ScheduleI_RecipientTable_IRCSectionDesc',
#  'ScheduleI_RecipientTable_CashGrantAmt',
#  'ScheduleI_RecipientTable_PurposeOfGrantTxt',
#  'ScheduleI_SupplementalInformationDetail_FormAndLineReferenceDesc',
#  'ScheduleI_SupplementalInformationDetail_ExplanationTxt',
#  'ScheduleM_at_documentId',
#  'ScheduleM_RealEstateOtherGrp_NonCashCheckboxInd',
#  'ScheduleM_RealEstateOtherGrp_ContributionCnt',
#  'ScheduleM_RealEstateOtherGrp_NoncashContributionsRptF990Amt',
#  'ScheduleM_RealEstateOtherGrp_MethodOfDeterminingRevenuesTxt',
#  'ScheduleM_AnyPropertyThatMustBeHeldInd',
#  'ScheduleM_ReviewProcessUnusualNCGiftsInd',
#  'ScheduleM_ThirdPartiesUsedInd',
#  'ScheduleO_at_documentId',
#  'ScheduleO_SupplementalInformationDetail_FormAndLineReferenceDesc',
#  'ScheduleO_SupplementalInformationDetail_ExplanationTxt']

# %%
len(outlist)
# Out:
# 470

# %%
with open('shorter key names', 'wb') as tofile:
    pickle.dump(outlist, tofile)

# %%
data = pandas.dataframe(blaha )
